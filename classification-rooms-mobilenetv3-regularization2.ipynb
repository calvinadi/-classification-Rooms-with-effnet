# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import random

import glob as gb
import cv2
import matplotlib.pylab as plt
plt.style.use('ggplot')

# %% [markdown]
# ### Dataset source: https://www.kaggle.com/datasets/annielu21/house-rooms

# %%
import warnings

warnings.filterwarnings("ignore", message="All log messages before absl::InitializeLog() is called are written to STDERR")
warnings.filterwarnings("ignore", message="Fallback to op-by-op mode because memset node breaks graph update")

# %%
from sklearn.model_selection import train_test_split
import os
import shutil
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
# Out:
# 2024-06-27 13:17:48.826849: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-27 13:17:48.826916: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-27 13:17:48.828493: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    tf.random.set_seed(random_seed)
    os.environ['PYTHONHASHSEED'] = str(random_seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'

# %%
set_random_seed(42)

# %%
# Path gambar
img_path = '/kaggle/input/processed-room-image/clahe_processed_images'

input_dir = 'images'
output_dir = 'output'

# Membuat folder output jika belum ada
os.makedirs(output_dir, exist_ok=True)

# %%
# Membuat Folder Kategori
categories = ['bathroom', 'bedroom', 'dining', 'gaming', 
              'kitchen','laundry','living', 'office',
             'terrace', 'yard']

for category in categories:
    category_dir = os.path.join(output_dir, category)
    os.makedirs(category_dir, exist_ok=True)

# %%
# Memindahkan file ke folder yang dipilih
for root, dirs, files in os.walk(img_path):
    for file in files:
        category = os.path.basename(root)
        if category in categories:
            source_file = os.path.join(root, file)
            destination_dir = os.path.join(output_dir, category)
            shutil.copy(source_file, destination_dir)

# Menampilkan jumlah file dalam setiap kategori
for category in categories:
    category_dir = os.path.join(output_dir, category)
    num_files = len(os.listdir(category_dir))
    print(f"Total {category} files: {num_files}")
# Out:
# Total bathroom files: 740
# Total bedroom files: 1083
# Total dining files: 1178
# Total gaming files: 1511
# Total kitchen files: 1208
# Total laundry files: 1589
# Total living files: 1164
# Total office files: 1241
# Total terrace files: 1210
# Total yard files: 1398

# %%
# Buat folder train, validation, dan test
train_dir = os.path.join(output_dir, "train")
val_dir = os.path.join(output_dir, "validation")
test_dir = os.path.join(output_dir, "test")

if os.path.exists(train_dir):
    shutil.rmtree(train_dir)
if os.path.exists(val_dir):
    shutil.rmtree(val_dir)
if os.path.exists(test_dir):
    shutil.rmtree(test_dir)
    
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# Split data menjadi train, validation, dan test
for category in categories:
    category_dir = os.path.join(output_dir, category)
    images = os.listdir(category_dir)
    
    # Pembagian train, validation, test (70%, 15%, 15%)
    train_images, val_test_images = train_test_split(images, test_size=0.4, random_state=42)
    val_images, test_images = train_test_split(val_test_images, test_size=0.5, random_state=42)
    
    # Pindahkan gambar-gambar ke dalam folder train, validation, dan test
    for img in train_images:
        target_dir = os.path.join(train_dir, category)
        os.makedirs(target_dir, exist_ok=True)
        shutil.move(os.path.join(category_dir, img), os.path.join(target_dir, img))

    for img in val_images:
        target_dir = os.path.join(val_dir, category)
        os.makedirs(target_dir, exist_ok=True)
        shutil.move(os.path.join(category_dir, img), os.path.join(target_dir, img))
        
    for img in test_images:
        target_dir = os.path.join(test_dir, category)
        os.makedirs(target_dir, exist_ok=True)
        shutil.move(os.path.join(category_dir, img), os.path.join(target_dir, img))

# %%
# Cetak jumlah gambar dalam folder train
print("\nJumlah Gambar dalam Folder Train:")
for category in categories:
    train_category_dir = os.path.join(train_dir, category)
    num_train_images = len(os.listdir(train_category_dir))
    print(f"{category}: {num_train_images} gambar")

# Cetak jumlah gambar dalam folder validation
print("\nJumlah Gambar dalam Folder Validation:")
for category in categories:
    val_category_dir = os.path.join(val_dir, category)
    num_val_images = len(os.listdir(val_category_dir))
    print(f"{category}: {num_val_images} gambar")

# Cetak jumlah gambar dalam folder test
print("\nJumlah Gambar dalam Folder Test:")
for category in categories:
    test_category_dir = os.path.join(test_dir, category)
    num_test_images = len(os.listdir(test_category_dir))
    print(f"{category}: {num_test_images} gambar")
# Out:
# Jumlah Gambar dalam Folder Train:
# bathroom: 444 gambar
# bedroom: 649 gambar
# dining: 706 gambar
# gaming: 906 gambar
# kitchen: 724 gambar
# laundry: 953 gambar
# living: 698 gambar
# office: 744 gambar
# terrace: 726 gambar
# yard: 838 gambar
#
# Jumlah Gambar dalam Folder Validation:
# bathroom: 148 gambar
# bedroom: 217 gambar
# dining: 236 gambar
# gaming: 302 gambar
# kitchen: 242 gambar
# laundry: 318 gambar
# living: 233 gambar
# office: 248 gambar
# terrace: 242 gambar
# yard: 280 gambar
#
# Jumlah Gambar dalam Folder Test:
# bathroom: 148 gambar
# bedroom: 217 gambar
# dining: 236 gambar
# gaming: 303 gambar
# kitchen: 242 gambar
# laundry: 318 gambar
# living: 233 gambar
# office: 249 gambar
# terrace: 242 gambar
# yard: 280 gambar

# %%
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def visualize_random_images(train_folder, val_folder, test_folder, num_images=1, figsize=(4, 4)):
    categories = os.listdir(train_folder)
    
    for category in categories:
        print(f"\nContoh Gambar untuk Kategori {category}:")
        fig, axes = plt.subplots(1, 3, figsize=(figsize[0] * 3, figsize[1]))

        folders = [train_folder, val_folder, test_folder]
        folder_names = ['Train', 'Validation', 'Test']
        
        for ax, folder, folder_name in zip(axes, folders, folder_names):
            category_dir = os.path.join(folder, category)
            images = os.listdir(category_dir)
            if len(images) > 0:
                img_file = random.choice(images)
                img_path = os.path.join(category_dir, img_file)
                img = mpimg.imread(img_path)
                ax.imshow(img)
                ax.axis("off")
                ax.set_title(folder_name)
            else:
                ax.axis("off")
                ax.set_title(f"No Images in {folder_name}")
        
        plt.show()

print('Visualizing Images for Categories:')
visualize_random_images(train_dir, val_dir, test_dir, figsize=(3, 3))
# Out:
# Visualizing Images for Categories:
#
# Contoh Gambar untuk Kategori living:
# Contoh Gambar untuk Kategori kitchen:
# Contoh Gambar untuk Kategori laundry:
# Contoh Gambar untuk Kategori yard:
# Contoh Gambar untuk Kategori office:
# Contoh Gambar untuk Kategori bathroom:
# Contoh Gambar untuk Kategori gaming:
# Contoh Gambar untuk Kategori dining:
# Contoh Gambar untuk Kategori bedroom:
# Contoh Gambar untuk Kategori terrace:

# %%
# Preprocess input images using MobilenetV3 preprocessing layers
preprocess_input = tf.keras.applications.mobilenet_v3.preprocess_input

# Menggunakan ImageDataGenerator untuk pelatihan 
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rescale=1./255,
    rotation_range=10, 
    zoom_range=0.1,
    width_shift_range=0.1, 
    height_shift_range=0.1, 
    shear_range=0.1,
    brightness_range=[0.8, 1.2],
    horizontal_flip=True,  
    vertical_flip=False,
    fill_mode='nearest'
)

traindata = train_datagen.flow_from_directory(
    directory=train_dir, 
    target_size=(224,224), 
    color_mode="rgb", 
    class_mode='categorical',
    shuffle=True)

val_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rescale=1./255
)

valdata = val_datagen.flow_from_directory(
    directory=val_dir, 
    target_size=(224,224), 
    color_mode="rgb", 
    class_mode='categorical',
    shuffle=False)

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rescale=1./255
)

testdata = test_datagen.flow_from_directory(
    directory=test_dir, 
    target_size=(224,224), 
    color_mode="rgb", 
    class_mode='categorical',
    shuffle=False)
# Out:
# Found 7382 images belonging to 10 classes.
# Found 2465 images belonging to 10 classes.
# Found 2464 images belonging to 10 classes.

# %%
print("Informasi Data Training:")
print(f"Jumlah sampel: {traindata.samples}")
print(f"Kelas: {traindata.class_indices}")
print(f"Shape gambar: {traindata.image_shape}")
print(f"Mode warna: {traindata.color_mode}")

print("\nInformasi Data Validasi:")
print(f"Jumlah sampel: {valdata.samples}")
print(f"Kelas: {valdata.class_indices}")
print(f"Shape gambar: {valdata.image_shape}")
print(f"Mode warna: {valdata.color_mode}")

print("\nInformasi Data Test:")
print(f"Jumlah sampel: {testdata.samples}")
print(f"Kelas: {testdata.class_indices}")
print(f"Shape gambar: {testdata.image_shape}")
print(f"Mode warna: {testdata.color_mode}")
# Out:
# Informasi Data Training:
# Jumlah sampel: 7382
# Kelas: {'bathroom': 0, 'bedroom': 1, 'dining': 2, 'gaming': 3, 'kitchen': 4, 'laundry': 5, 'living': 6, 'office': 7, 'terrace': 8, 'yard': 9}
# Shape gambar: (224, 224, 3)
# Mode warna: rgb
#
# Informasi Data Validasi:
# Jumlah sampel: 2465
# Kelas: {'bathroom': 0, 'bedroom': 1, 'dining': 2, 'gaming': 3, 'kitchen': 4, 'laundry': 5, 'living': 6, 'office': 7, 'terrace': 8, 'yard': 9}
# Shape gambar: (224, 224, 3)
# Mode warna: rgb
#
# Informasi Data Test:
# Jumlah sampel: 2464
# Kelas: {'bathroom': 0, 'bedroom': 1, 'dining': 2, 'gaming': 3, 'kitchen': 4, 'laundry': 5, 'living': 6, 'office': 7, 'terrace': 8, 'yard': 9}
# Shape gambar: (224, 224, 3)
# Mode warna: rgb

# %% [markdown]
# ### MODELING

# %%
from tensorflow.keras.applications import MobileNetV3Small

base_model = MobileNetV3Small(input_shape = (224, 224, 3), include_top = False, weights = 'imagenet')

# %%
# Freeze layers except the last 8 layers
for layer in base_model.layers[:-8]:
    layer.trainable = False

# %%
# Check if GPU is available
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    # Set memory growth for GPU
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# Physical devices cannot be modified after being initialized

# %%
# from tensorflow import keras
# from tensorflow.keras.models import *
# from tensorflow.keras.layers import *
# from keras.regularizers import l2
# import tensorflow as tf


# model = Sequential()
# model.add(Input(shape=(224, 224, 3)))
# model.add(base_model)
# model.add(Conv2D(512, (3, 3), activation='elu'))
# model.add(Conv2D(256, (3, 3), activation='elu'))
# model.add(GlobalAveragePooling2D())
# model.add(Dense(1024, activation='elu'))
# model.add(Dense(512, activation='elu'))
# model.add(Dense(len(categories), activation='softmax'))


# model.summary()

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# Function to create and compile model with given parameters
def create_model(dropout_rate, l2_reg):
    # Pre-trained model
    base_model = MobileNetV3Small(input_shape=(224, 224, 3), include_top=False, weights='imagenet')

    # Freeze layers except the last 8 layers
    for layer in base_model.layers[:-8]:
        layer.trainable = False
    
    # Initialize the model
    model = Sequential()
    # Add the base model
    model.add(Input(shape=(224, 224, 3)))
    model.add(base_model)
    model.add(Conv2D(512, (3, 3), activation='elu', kernel_regularizer=l2(l2_reg)))
    model.add(Conv2D(256, (3, 3), activation='elu', kernel_regularizer=l2(l2_reg)))
    # Global Average Pooling layer
    model.add(GlobalAveragePooling2D())
    # Dense layers with dropout
    model.add(Dense(1024, activation='elu', kernel_regularizer=l2(l2_reg)))
    model.add(Dropout(dropout_rate))  # Dropout for regularization
    model.add(Dense(512, activation='elu', kernel_regularizer=l2(l2_reg)))
    model.add(Dropout(dropout_rate))  # Dropout for regularization
    model.add(Dense(len(categories), activation='softmax'))

    # Compile the model
    optimizer = RMSprop(learning_rate=0.0001)
    model.compile(optimizer=optimizer,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# Define hyperparameters for experiments
dropout_rates = [0.3, 0.5, 0.4, 0.6, 0.2]
l2_regs = [0.001, 0.01, 0.0001, 0.00001, 0.000001]

# Callbacks
# Early stopping for val_accuracy
early_stopping_acc = EarlyStopping(monitor='val_accuracy', patience=10, 
                                   restore_best_weights=True, mode='max')

# Early stopping for val_loss
early_stopping_loss = EarlyStopping(monitor='val_loss', patience=5, 
                                    restore_best_weights=True, mode='min')

# Reduce learning rate when a metric has stopped improving
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, 
                              patience=4, min_lr=0.000005, verbose=1)

# Callback ModelCheckpoint untuk menyimpan bobot terbaik
modelpath = './output/bestmodel.keras'
checkpoint = ModelCheckpoint(
    modelpath,
    monitor='val_accuracy',
    save_best_only=True,  # Hanya menyimpan bobot terbaik
    mode='max',  # Mode untuk membandingkan nilai metrik (misalnya 'max' untuk akurasi)
    verbose=1  # Menampilkan pesan saat menyimpan
)

# Perform 10 experiments
models = []
for dropout_rate in dropout_rates:
    for l2_reg in l2_regs:
        model = create_model(dropout_rate, l2_reg)
        models.append(model)

# Train and evaluate each model
for i, model in enumerate(models):
    print(f"Experiment {i+1}: Dropout={dropout_rates[i // len(l2_regs)]}, L2 regularization={l2_regs[i % len(l2_regs)]}")
    # Train the model with your data
    history = model.fit(x=traindata, validation_data=valdata, epochs=200, 
                        batch_size=64, callbacks=[early_stopping_acc, early_stopping_loss,
                                                  reduce_lr, checkpoint])
    
    # Evaluate the model on test data (replace with your test data evaluation)
    test_loss, test_acc = model.evaluate(testdata)
    print(f'Test Loss: {test_loss:.4f}')
    print(f'Test Accuracy: {test_acc * 100:.2f}%')
    print("\n")
# Out:
# Experiment 1: Dropout=0.3, L2 regularization=0.001
# Epoch 1/200
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   1/231 ━━━━━━━━━━━━━━━━━━━━ 1:06:26 17s/step - accuracy: 0.1250 - loss: 4.3063
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1719494340.423002     410 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.1571 - loss: 4.2202
# Epoch 1: val_accuracy improved from -inf to 0.06247, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 122s 457ms/step - accuracy: 0.1572 - loss: 4.2197 - val_accuracy: 0.0625 - val_loss: 4.2281 - learning_rate: 1.0000e-04
# Epoch 2/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.2286 - loss: 3.8784
# Epoch 2: val_accuracy improved from 0.06247 to 0.09817, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 392ms/step - accuracy: 0.2287 - loss: 3.8781 - val_accuracy: 0.0982 - val_loss: 4.0880 - learning_rate: 1.0000e-04
# Epoch 3/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.2581 - loss: 3.7033
# Epoch 3: val_accuracy improved from 0.09817 to 0.11278, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 393ms/step - accuracy: 0.2582 - loss: 3.7029 - val_accuracy: 0.1128 - val_loss: 4.0371 - learning_rate: 1.0000e-04
# Epoch 4/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.2755 - loss: 3.5469
# Epoch 4: val_accuracy did not improve from 0.11278
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 391ms/step - accuracy: 0.2755 - loss: 3.5466 - val_accuracy: 0.0982 - val_loss: 4.0333 - learning_rate: 1.0000e-04
# Epoch 5/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.2845 - loss: 3.3954
# Epoch 5: val_accuracy improved from 0.11278 to 0.13631, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 390ms/step - accuracy: 0.2845 - loss: 3.3951 - val_accuracy: 0.1363 - val_loss: 3.9727 - learning_rate: 1.0000e-04
# Epoch 6/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.2930 - loss: 3.2670
# Epoch 6: val_accuracy did not improve from 0.13631
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 389ms/step - accuracy: 0.2931 - loss: 3.2667 - val_accuracy: 0.0986 - val_loss: 4.1689 - learning_rate: 1.0000e-04
# Epoch 7/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.3064 - loss: 3.1416
# Epoch 7: val_accuracy did not improve from 0.13631
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 391ms/step - accuracy: 0.3064 - loss: 3.1415 - val_accuracy: 0.1168 - val_loss: 3.8273 - learning_rate: 1.0000e-04
# Epoch 8/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.3043 - loss: 3.0587
# Epoch 8: val_accuracy did not improve from 0.13631
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 386ms/step - accuracy: 0.3044 - loss: 3.0584 - val_accuracy: 0.0982 - val_loss: 3.8548 - learning_rate: 1.0000e-04
# Epoch 9/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.3123 - loss: 2.9495
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 9: val_accuracy did not improve from 0.13631
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 142s 386ms/step - accuracy: 0.3124 - loss: 2.9493 - val_accuracy: 0.0982 - val_loss: 4.0709 - learning_rate: 1.0000e-04
# Epoch 10/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.3401 - loss: 2.8345
# Epoch 10: val_accuracy did not improve from 0.13631
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 388ms/step - accuracy: 0.3402 - loss: 2.8343 - val_accuracy: 0.0994 - val_loss: 4.0209 - learning_rate: 1.0000e-05
# Epoch 11/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.3518 - loss: 2.7929
# Epoch 11: val_accuracy did not improve from 0.13631
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 390ms/step - accuracy: 0.3518 - loss: 2.7928 - val_accuracy: 0.1022 - val_loss: 4.0533 - learning_rate: 1.0000e-05
# Epoch 12/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.3590 - loss: 2.7665
# Epoch 12: val_accuracy did not improve from 0.13631
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 390ms/step - accuracy: 0.3590 - loss: 2.7666 - val_accuracy: 0.1018 - val_loss: 4.1437 - learning_rate: 1.0000e-05
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.0999 - loss: 3.6897
# Test Loss: 3.8178
# Test Accuracy: 12.13%
#
#
# Experiment 2: Dropout=0.3, L2 regularization=0.01
# Epoch 1/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.1619 - loss: 19.1172
# Epoch 1: val_accuracy did not improve from 0.13631
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 120s 450ms/step - accuracy: 0.1621 - loss: 19.0948 - val_accuracy: 0.1318 - val_loss: 12.1534 - learning_rate: 1.0000e-04
# Epoch 2/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.2282 - loss: 10.3710
# Epoch 2: val_accuracy did not improve from 0.13631
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 391ms/step - accuracy: 0.2282 - loss: 10.3588 - val_accuracy: 0.1225 - val_loss: 6.7709 - learning_rate: 1.0000e-04
# Epoch 3/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.2477 - loss: 5.6900
# Epoch 3: val_accuracy did not improve from 0.13631
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 389ms/step - accuracy: 0.2477 - loss: 5.6841 - val_accuracy: 0.1290 - val_loss: 4.1628 - learning_rate: 1.0000e-04
# Epoch 4/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.2599 - loss: 3.5538
# Epoch 4: val_accuracy did not improve from 0.13631
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 388ms/step - accuracy: 0.2599 - loss: 3.5515 - val_accuracy: 0.1225 - val_loss: 3.2032 - learning_rate: 1.0000e-04
# Epoch 5/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.2685 - loss: 2.7065
# Epoch 5: val_accuracy improved from 0.13631 to 0.13834, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 391ms/step - accuracy: 0.2685 - loss: 2.7057 - val_accuracy: 0.1383 - val_loss: 2.7664 - learning_rate: 1.0000e-04
# Epoch 6/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.2750 - loss: 2.3871
# Epoch 6: val_accuracy did not improve from 0.13834
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 384ms/step - accuracy: 0.2750 - loss: 2.3866 - val_accuracy: 0.1290 - val_loss: 2.5828 - learning_rate: 1.0000e-04
# Epoch 7/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.2698 - loss: 2.2515
# Epoch 7: val_accuracy did not improve from 0.13834
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 386ms/step - accuracy: 0.2699 - loss: 2.2512 - val_accuracy: 0.1290 - val_loss: 2.5274 - learning_rate: 1.0000e-04
# Epoch 8/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.2749 - loss: 2.1760
# Epoch 8: val_accuracy did not improve from 0.13834
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 384ms/step - accuracy: 0.2750 - loss: 2.1758 - val_accuracy: 0.1327 - val_loss: 2.4980 - learning_rate: 1.0000e-04
# Epoch 9/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.2956 - loss: 2.1117
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 9: val_accuracy did not improve from 0.13834
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.2955 - loss: 2.1117 - val_accuracy: 0.1290 - val_loss: 2.4347 - learning_rate: 1.0000e-04
# Epoch 10/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.3024 - loss: 2.0663
# Epoch 10: val_accuracy did not improve from 0.13834
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 141s 386ms/step - accuracy: 0.3024 - loss: 2.0663 - val_accuracy: 0.1310 - val_loss: 2.4154 - learning_rate: 1.0000e-05
# Epoch 11/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.3105 - loss: 2.0600
# Epoch 11: val_accuracy did not improve from 0.13834
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 143s 388ms/step - accuracy: 0.3105 - loss: 2.0600 - val_accuracy: 0.1359 - val_loss: 2.4014 - learning_rate: 1.0000e-05
# Epoch 12/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.3047 - loss: 2.0650
# Epoch 12: val_accuracy improved from 0.13834 to 0.14483, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 391ms/step - accuracy: 0.3047 - loss: 2.0650 - val_accuracy: 0.1448 - val_loss: 2.3809 - learning_rate: 1.0000e-05
# Epoch 13/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.3068 - loss: 2.0628
# Epoch 13: val_accuracy improved from 0.14483 to 0.17120, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 390ms/step - accuracy: 0.3068 - loss: 2.0628 - val_accuracy: 0.1712 - val_loss: 2.3351 - learning_rate: 1.0000e-05
# Epoch 14/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.3076 - loss: 2.0451
# Epoch 14: val_accuracy improved from 0.17120 to 0.17769, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 390ms/step - accuracy: 0.3076 - loss: 2.0452 - val_accuracy: 0.1777 - val_loss: 2.3196 - learning_rate: 1.0000e-05
# Epoch 15/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.3109 - loss: 2.0551
# Epoch 15: val_accuracy improved from 0.17769 to 0.21339, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 391ms/step - accuracy: 0.3109 - loss: 2.0550 - val_accuracy: 0.2134 - val_loss: 2.2635 - learning_rate: 1.0000e-05
# Epoch 16/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.3199 - loss: 2.0356
# Epoch 16: val_accuracy improved from 0.21339 to 0.23043, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 393ms/step - accuracy: 0.3198 - loss: 2.0357 - val_accuracy: 0.2304 - val_loss: 2.2385 - learning_rate: 1.0000e-05
# Epoch 17/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.3212 - loss: 2.0153
# Epoch 17: val_accuracy improved from 0.23043 to 0.25112, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 394ms/step - accuracy: 0.3212 - loss: 2.0155 - val_accuracy: 0.2511 - val_loss: 2.2048 - learning_rate: 1.0000e-05
# Epoch 18/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.3059 - loss: 2.0411
# Epoch 18: val_accuracy improved from 0.25112 to 0.27667, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 389ms/step - accuracy: 0.3060 - loss: 2.0411 - val_accuracy: 0.2767 - val_loss: 2.1616 - learning_rate: 1.0000e-05
# Epoch 19/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.3204 - loss: 2.0167
# Epoch 19: val_accuracy improved from 0.27667 to 0.29290, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 143s 393ms/step - accuracy: 0.3203 - loss: 2.0168 - val_accuracy: 0.2929 - val_loss: 2.1234 - learning_rate: 1.0000e-05
# Epoch 20/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.3176 - loss: 2.0113
# Epoch 20: val_accuracy did not improve from 0.29290
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 391ms/step - accuracy: 0.3175 - loss: 2.0115 - val_accuracy: 0.2876 - val_loss: 2.1233 - learning_rate: 1.0000e-05
# Epoch 21/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.3150 - loss: 2.0445
# Epoch 21: val_accuracy improved from 0.29290 to 0.30913, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.3150 - loss: 2.0444 - val_accuracy: 0.3091 - val_loss: 2.0744 - learning_rate: 1.0000e-05
# Epoch 22/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.3192 - loss: 2.0290
# Epoch 22: val_accuracy did not improve from 0.30913
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 385ms/step - accuracy: 0.3192 - loss: 2.0290 - val_accuracy: 0.3030 - val_loss: 2.0723 - learning_rate: 1.0000e-05
# Epoch 23/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.3191 - loss: 2.0170
# Epoch 23: val_accuracy did not improve from 0.30913
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.3191 - loss: 2.0170 - val_accuracy: 0.3026 - val_loss: 2.0612 - learning_rate: 1.0000e-05
# Epoch 24/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.3136 - loss: 2.0314
# Epoch 24: val_accuracy improved from 0.30913 to 0.31886, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 390ms/step - accuracy: 0.3136 - loss: 2.0313 - val_accuracy: 0.3189 - val_loss: 2.0382 - learning_rate: 1.0000e-05
# Epoch 25/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.3236 - loss: 2.0073
# Epoch 25: val_accuracy improved from 0.31886 to 0.31927, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 391ms/step - accuracy: 0.3236 - loss: 2.0074 - val_accuracy: 0.3193 - val_loss: 2.0344 - learning_rate: 1.0000e-05
# Epoch 26/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.3192 - loss: 2.0226
# Epoch 26: val_accuracy did not improve from 0.31927
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 386ms/step - accuracy: 0.3192 - loss: 2.0225 - val_accuracy: 0.3022 - val_loss: 2.0474 - learning_rate: 1.0000e-05
# Epoch 27/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.3264 - loss: 2.0262
# Epoch 27: val_accuracy improved from 0.31927 to 0.32373, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 389ms/step - accuracy: 0.3264 - loss: 2.0261 - val_accuracy: 0.3237 - val_loss: 2.0136 - learning_rate: 1.0000e-05
# Epoch 28/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.3146 - loss: 2.0147
# Epoch 28: val_accuracy did not improve from 0.32373
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 389ms/step - accuracy: 0.3146 - loss: 2.0147 - val_accuracy: 0.3156 - val_loss: 2.0178 - learning_rate: 1.0000e-05
# Epoch 29/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.3306 - loss: 2.0131
# Epoch 29: val_accuracy did not improve from 0.32373
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 390ms/step - accuracy: 0.3305 - loss: 2.0131 - val_accuracy: 0.3237 - val_loss: 2.0117 - learning_rate: 1.0000e-05
# Epoch 30/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.3259 - loss: 1.9999
# Epoch 30: val_accuracy improved from 0.32373 to 0.32738, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 390ms/step - accuracy: 0.3259 - loss: 2.0000 - val_accuracy: 0.3274 - val_loss: 2.0059 - learning_rate: 1.0000e-05
# Epoch 31/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.3182 - loss: 2.0212
# Epoch 31: val_accuracy did not improve from 0.32738
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 388ms/step - accuracy: 0.3182 - loss: 2.0210 - val_accuracy: 0.3164 - val_loss: 2.0141 - learning_rate: 1.0000e-05
# Epoch 32/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.3255 - loss: 2.0107
# Epoch 32: val_accuracy did not improve from 0.32738
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.3255 - loss: 2.0107 - val_accuracy: 0.3233 - val_loss: 2.0024 - learning_rate: 1.0000e-05
# Epoch 33/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.3179 - loss: 2.0010
# Epoch 33: val_accuracy did not improve from 0.32738
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 388ms/step - accuracy: 0.3179 - loss: 2.0011 - val_accuracy: 0.3221 - val_loss: 2.0163 - learning_rate: 1.0000e-05
# Epoch 34/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.3268 - loss: 2.0047
# Epoch 34: val_accuracy improved from 0.32738 to 0.32941, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 391ms/step - accuracy: 0.3268 - loss: 2.0047 - val_accuracy: 0.3294 - val_loss: 2.0019 - learning_rate: 1.0000e-05
# Epoch 35/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.3297 - loss: 2.0022
# Epoch 35: val_accuracy did not improve from 0.32941
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 142s 388ms/step - accuracy: 0.3297 - loss: 2.0023 - val_accuracy: 0.3274 - val_loss: 2.0055 - learning_rate: 1.0000e-05
# Epoch 36/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.3245 - loss: 2.0033
# Epoch 36: val_accuracy improved from 0.32941 to 0.33103, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 392ms/step - accuracy: 0.3245 - loss: 2.0033 - val_accuracy: 0.3310 - val_loss: 1.9949 - learning_rate: 1.0000e-05
# Epoch 37/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.3265 - loss: 1.9981
# Epoch 37: val_accuracy did not improve from 0.33103
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 388ms/step - accuracy: 0.3264 - loss: 1.9981 - val_accuracy: 0.3270 - val_loss: 1.9975 - learning_rate: 1.0000e-05
# Epoch 38/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.3339 - loss: 1.9915
# Epoch 38: val_accuracy did not improve from 0.33103
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 385ms/step - accuracy: 0.3338 - loss: 1.9916 - val_accuracy: 0.3258 - val_loss: 1.9980 - learning_rate: 1.0000e-05
# Epoch 39/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.3303 - loss: 1.9988
# Epoch 39: val_accuracy did not improve from 0.33103
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.3303 - loss: 1.9989 - val_accuracy: 0.3249 - val_loss: 2.0116 - learning_rate: 1.0000e-05
# Epoch 40/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.3290 - loss: 1.9992
# Epoch 40: ReduceLROnPlateau reducing learning rate to 5e-06.
#
# Epoch 40: val_accuracy did not improve from 0.33103
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 388ms/step - accuracy: 0.3290 - loss: 1.9992 - val_accuracy: 0.3302 - val_loss: 1.9885 - learning_rate: 1.0000e-05
# Epoch 41/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.3250 - loss: 1.9930
# Epoch 41: val_accuracy improved from 0.33103 to 0.33347, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 391ms/step - accuracy: 0.3250 - loss: 1.9930 - val_accuracy: 0.3335 - val_loss: 1.9874 - learning_rate: 5.0000e-06
# Epoch 42/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.3277 - loss: 2.0061
# Epoch 42: val_accuracy did not improve from 0.33347
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 386ms/step - accuracy: 0.3277 - loss: 2.0061 - val_accuracy: 0.3282 - val_loss: 1.9937 - learning_rate: 5.0000e-06
# Epoch 43/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.3289 - loss: 1.9924
# Epoch 43: val_accuracy improved from 0.33347 to 0.33955, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 394ms/step - accuracy: 0.3290 - loss: 1.9924 - val_accuracy: 0.3396 - val_loss: 1.9848 - learning_rate: 5.0000e-06
# Epoch 44/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.3362 - loss: 1.9859
# Epoch 44: val_accuracy did not improve from 0.33955
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 389ms/step - accuracy: 0.3361 - loss: 1.9859 - val_accuracy: 0.3286 - val_loss: 1.9923 - learning_rate: 5.0000e-06
# Epoch 45/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.3236 - loss: 1.9961
# Epoch 45: val_accuracy did not improve from 0.33955
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 391ms/step - accuracy: 0.3237 - loss: 1.9960 - val_accuracy: 0.3351 - val_loss: 1.9842 - learning_rate: 5.0000e-06
# Epoch 46/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.3210 - loss: 1.9974
# Epoch 46: val_accuracy did not improve from 0.33955
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 141s 390ms/step - accuracy: 0.3210 - loss: 1.9974 - val_accuracy: 0.3351 - val_loss: 1.9829 - learning_rate: 5.0000e-06
# Epoch 47/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.3380 - loss: 1.9856
# Epoch 47: val_accuracy did not improve from 0.33955
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 388ms/step - accuracy: 0.3379 - loss: 1.9856 - val_accuracy: 0.3331 - val_loss: 1.9898 - learning_rate: 5.0000e-06
# Epoch 48/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.3339 - loss: 1.9895
# Epoch 48: val_accuracy did not improve from 0.33955
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 386ms/step - accuracy: 0.3339 - loss: 1.9895 - val_accuracy: 0.3318 - val_loss: 1.9882 - learning_rate: 5.0000e-06
# Epoch 49/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.3229 - loss: 2.0001
# Epoch 49: val_accuracy did not improve from 0.33955
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 386ms/step - accuracy: 0.3230 - loss: 2.0000 - val_accuracy: 0.3306 - val_loss: 1.9886 - learning_rate: 5.0000e-06
# Epoch 50/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.3330 - loss: 1.9882
# Epoch 50: val_accuracy did not improve from 0.33955
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 385ms/step - accuracy: 0.3330 - loss: 1.9883 - val_accuracy: 0.3363 - val_loss: 1.9832 - learning_rate: 5.0000e-06
# Epoch 51/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.3400 - loss: 1.9889
# Epoch 51: val_accuracy did not improve from 0.33955
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.3399 - loss: 1.9889 - val_accuracy: 0.3314 - val_loss: 1.9837 - learning_rate: 5.0000e-06
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - accuracy: 0.2649 - loss: 2.1756
# Test Loss: 1.9447
# Test Accuracy: 34.13%
#
#
# Experiment 3: Dropout=0.3, L2 regularization=0.0001
# Epoch 1/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.1647 - loss: 2.4914
# Epoch 1: val_accuracy did not improve from 0.33955
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 120s 451ms/step - accuracy: 0.1649 - loss: 2.4907 - val_accuracy: 0.1400 - val_loss: 2.4885 - learning_rate: 1.0000e-04
# Epoch 2/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.2210 - loss: 2.3305
# Epoch 2: val_accuracy did not improve from 0.33955
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.2211 - loss: 2.3302 - val_accuracy: 0.0994 - val_loss: 2.4913 - learning_rate: 1.0000e-04
# Epoch 3/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.2511 - loss: 2.2520
# Epoch 3: val_accuracy did not improve from 0.33955
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 386ms/step - accuracy: 0.2511 - loss: 2.2519 - val_accuracy: 0.0982 - val_loss: 2.5322 - learning_rate: 1.0000e-04
# Epoch 4/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.2713 - loss: 2.2274
# Epoch 4: val_accuracy did not improve from 0.33955
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 390ms/step - accuracy: 0.2713 - loss: 2.2274 - val_accuracy: 0.0982 - val_loss: 2.6229 - learning_rate: 1.0000e-04
# Epoch 5/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.2880 - loss: 2.1789
# Epoch 5: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 5: val_accuracy did not improve from 0.33955
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 389ms/step - accuracy: 0.2879 - loss: 2.1790 - val_accuracy: 0.1172 - val_loss: 2.6848 - learning_rate: 1.0000e-04
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - accuracy: 0.0657 - loss: 2.5485
# Test Loss: 2.4936
# Test Accuracy: 13.51%
#
#
# Experiment 4: Dropout=0.3, L2 regularization=1e-05
# Epoch 1/200
# 212/231 ━━━━━━━━━━━━━━━━━━━━ 7s 414ms/step - accuracy: 0.1650 - loss: 2.3220

# %%
# import tensorflow as tf
# from tensorflow.keras.optimizers import SGD, Adam, RMSprop
# from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# device_name = tf.test.gpu_device_name()
# modelpath = './output/bestmodel.keras'


# ### train the model
# with tf.device(device_name):
    
#     optimizer = RMSprop(learning_rate=0.0001)
    
#     model.compile(
#       optimizer=optimizer,
#       loss='categorical_crossentropy',
#       metrics=['accuracy'])
    
#     # Early stopping for val_accuracy
#     early_stopping_acc = EarlyStopping(monitor='val_accuracy', patience=10, 
#                                        restore_best_weights=True, mode='max')

#     # Early stopping for val_loss
#     early_stopping_loss = EarlyStopping(monitor='val_loss', patience=5, 
#                                         restore_best_weights=True, mode='min')

    
#     # Reduce learning rate when a metric has stopped improving
#     reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, 
#                                   patience=4, min_lr=0.000005, verbose=1)

    
#     # Callback ModelCheckpoint untuk menyimpan bobot terbaik
#     checkpoint = ModelCheckpoint(
#         modelpath,
#         monitor='val_accuracy',
#         save_best_only=True,  # Hanya menyimpan bobot terbaik
#         mode='max',  # Mode untuk membandingkan nilai metrik (misalnya 'max' untuk akurasi)
#         verbose=1  # Menampilkan pesan saat menyimpan
#     )

#     # Train the model
#     history = model.fit(x=traindata, validation_data=valdata, epochs=200, 
#                         batch_size=64, callbacks=[early_stopping_acc, early_stopping_loss,
#                                                   checkpoint])

# %%
# Evaluasi model pada data test
test_loss, test_acc = model.evaluate(testdata)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_acc * 100:.2f}%')

# %%
# Visualize the model

plt.plot(history.history['accuracy'], marker='o')
plt.plot(history.history['val_accuracy'], marker='o')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'], marker='o')
plt.plot(history.history['val_loss'], marker='o')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

# Prediksi label kelas menggunakan model terhadap data uji
predictions = model.predict(testdata)
predicted_classes = np.argmax(predictions, axis=1)

# Ambil label sebenarnya dari data uji
true_classes = testdata.labels

# Dapatkan nama kelas
class_labels = list(testdata.class_indices.keys())

# Buat classification matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Print classification matrix
print("Classification Matrix:")
print(cm)

# Print classification report
print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))

# %% [markdown]
# Accuracy adalah rasio dari jumlah prediksi yang benar (true predictions) dibagi dengan jumlah total instance dalam dataset.

# %% [markdown]
# Precision mengukur seberapa akurat model dalam memprediksi kelas positif. Ini dihitung sebagai rasio dari true positive (TP) dibagi oleh jumlah true positive dan false positive (FP).

# %% [markdown]
#  Recall mengukur seberapa baik model dalam menemukan semua instance yang benar dari kelas yang diinginkan. Ini dihitung sebagai rasio dari true positive (TP) dibagi oleh jumlah true positive dan false negative (FN).

# %% [markdown]
# F1-score adalah rata-rata harmonik dari precision dan recall. Ini memberikan keseimbangan antara precision dan recall.
