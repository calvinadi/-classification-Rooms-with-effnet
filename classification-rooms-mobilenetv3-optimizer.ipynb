# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import random

import glob as gb
import cv2
import matplotlib.pylab as plt
plt.style.use('ggplot')

# %% [markdown]
# ### Dataset source: https://www.kaggle.com/datasets/annielu21/house-rooms

# %%
import warnings

warnings.filterwarnings("ignore", message="All log messages before absl::InitializeLog() is called are written to STDERR")
warnings.filterwarnings("ignore", message="Fallback to op-by-op mode because memset node breaks graph update")

# %%
from sklearn.model_selection import train_test_split
import os
import shutil
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
# Out:
# 2024-06-26 11:50:59.411201: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-26 11:50:59.411264: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-26 11:50:59.412859: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    tf.random.set_seed(random_seed)
    os.environ['PYTHONHASHSEED'] = str(random_seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'

# %%
set_random_seed(42)

# %%
# Path gambar
img_path = '/kaggle/input/processed-room-image/clahe_processed_images'

input_dir = 'images'
output_dir = 'output'

# Membuat folder output jika belum ada
os.makedirs(output_dir, exist_ok=True)

# %%
# Membuat Folder Kategori
categories = ['bathroom', 'bedroom', 'dining', 'gaming', 
              'kitchen','laundry','living', 'office',
             'terrace', 'yard']

for category in categories:
    category_dir = os.path.join(output_dir, category)
    os.makedirs(category_dir, exist_ok=True)

# %%
# Memindahkan file ke folder yang dipilih
for root, dirs, files in os.walk(img_path):
    for file in files:
        category = os.path.basename(root)
        if category in categories:
            source_file = os.path.join(root, file)
            destination_dir = os.path.join(output_dir, category)
            shutil.copy(source_file, destination_dir)

# Menampilkan jumlah file dalam setiap kategori
for category in categories:
    category_dir = os.path.join(output_dir, category)
    num_files = len(os.listdir(category_dir))
    print(f"Total {category} files: {num_files}")
# Out:
# Total bathroom files: 740
# Total bedroom files: 1083
# Total dining files: 1178
# Total gaming files: 1511
# Total kitchen files: 1208
# Total laundry files: 1589
# Total living files: 1164
# Total office files: 1241
# Total terrace files: 1210
# Total yard files: 1398

# %%
# Buat folder train, validation, dan test
train_dir = os.path.join(output_dir, "train")
val_dir = os.path.join(output_dir, "validation")
test_dir = os.path.join(output_dir, "test")

if os.path.exists(train_dir):
    shutil.rmtree(train_dir)
if os.path.exists(val_dir):
    shutil.rmtree(val_dir)
if os.path.exists(test_dir):
    shutil.rmtree(test_dir)
    
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# Split data menjadi train, validation, dan test
for category in categories:
    category_dir = os.path.join(output_dir, category)
    images = os.listdir(category_dir)
    
    # Pembagian train, validation, test (70%, 15%, 15%)
    train_images, val_test_images = train_test_split(images, test_size=0.4, random_state=42)
    val_images, test_images = train_test_split(val_test_images, test_size=0.5, random_state=42)
    
    # Pindahkan gambar-gambar ke dalam folder train, validation, dan test
    for img in train_images:
        target_dir = os.path.join(train_dir, category)
        os.makedirs(target_dir, exist_ok=True)
        shutil.move(os.path.join(category_dir, img), os.path.join(target_dir, img))

    for img in val_images:
        target_dir = os.path.join(val_dir, category)
        os.makedirs(target_dir, exist_ok=True)
        shutil.move(os.path.join(category_dir, img), os.path.join(target_dir, img))
        
    for img in test_images:
        target_dir = os.path.join(test_dir, category)
        os.makedirs(target_dir, exist_ok=True)
        shutil.move(os.path.join(category_dir, img), os.path.join(target_dir, img))

# %%
# Cetak jumlah gambar dalam folder train
print("\nJumlah Gambar dalam Folder Train:")
for category in categories:
    train_category_dir = os.path.join(train_dir, category)
    num_train_images = len(os.listdir(train_category_dir))
    print(f"{category}: {num_train_images} gambar")

# Cetak jumlah gambar dalam folder validation
print("\nJumlah Gambar dalam Folder Validation:")
for category in categories:
    val_category_dir = os.path.join(val_dir, category)
    num_val_images = len(os.listdir(val_category_dir))
    print(f"{category}: {num_val_images} gambar")

# Cetak jumlah gambar dalam folder test
print("\nJumlah Gambar dalam Folder Test:")
for category in categories:
    test_category_dir = os.path.join(test_dir, category)
    num_test_images = len(os.listdir(test_category_dir))
    print(f"{category}: {num_test_images} gambar")
# Out:
# Jumlah Gambar dalam Folder Train:
# bathroom: 444 gambar
# bedroom: 649 gambar
# dining: 706 gambar
# gaming: 906 gambar
# kitchen: 724 gambar
# laundry: 953 gambar
# living: 698 gambar
# office: 744 gambar
# terrace: 726 gambar
# yard: 838 gambar
#
# Jumlah Gambar dalam Folder Validation:
# bathroom: 148 gambar
# bedroom: 217 gambar
# dining: 236 gambar
# gaming: 302 gambar
# kitchen: 242 gambar
# laundry: 318 gambar
# living: 233 gambar
# office: 248 gambar
# terrace: 242 gambar
# yard: 280 gambar
#
# Jumlah Gambar dalam Folder Test:
# bathroom: 148 gambar
# bedroom: 217 gambar
# dining: 236 gambar
# gaming: 303 gambar
# kitchen: 242 gambar
# laundry: 318 gambar
# living: 233 gambar
# office: 249 gambar
# terrace: 242 gambar
# yard: 280 gambar

# %%
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def visualize_random_images(train_folder, val_folder, test_folder, num_images=1, figsize=(4, 4)):
    categories = os.listdir(train_folder)
    
    for category in categories:
        print(f"\nContoh Gambar untuk Kategori {category}:")
        fig, axes = plt.subplots(1, 3, figsize=(figsize[0] * 3, figsize[1]))

        folders = [train_folder, val_folder, test_folder]
        folder_names = ['Train', 'Validation', 'Test']
        
        for ax, folder, folder_name in zip(axes, folders, folder_names):
            category_dir = os.path.join(folder, category)
            images = os.listdir(category_dir)
            if len(images) > 0:
                img_file = random.choice(images)
                img_path = os.path.join(category_dir, img_file)
                img = mpimg.imread(img_path)
                ax.imshow(img)
                ax.axis("off")
                ax.set_title(folder_name)
            else:
                ax.axis("off")
                ax.set_title(f"No Images in {folder_name}")
        
        plt.show()

print('Visualizing Images for Categories:')
visualize_random_images(train_dir, val_dir, test_dir, figsize=(3, 3))
# Out:
# Visualizing Images for Categories:
#
# Contoh Gambar untuk Kategori kitchen:
# Contoh Gambar untuk Kategori living:
# Contoh Gambar untuk Kategori bedroom:
# Contoh Gambar untuk Kategori yard:
# Contoh Gambar untuk Kategori laundry:
# Contoh Gambar untuk Kategori terrace:
# Contoh Gambar untuk Kategori office:
# Contoh Gambar untuk Kategori gaming:
# Contoh Gambar untuk Kategori bathroom:
# Contoh Gambar untuk Kategori dining:

# %%
# Preprocess input images using MobilenetV3 preprocessing layers
preprocess_input = tf.keras.applications.mobilenet_v3.preprocess_input

# Menggunakan ImageDataGenerator untuk pelatihan 
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rescale=1./255,
    rotation_range=10, 
    zoom_range=0.1,
    width_shift_range=0.1, 
    height_shift_range=0.1, 
    shear_range=0.1,
    brightness_range=[0.8, 1.2],
    horizontal_flip=True,  
    vertical_flip=False,
    fill_mode='nearest'
)

traindata = train_datagen.flow_from_directory(
    directory=train_dir, 
    target_size=(224,224), 
    color_mode="rgb", 
    class_mode='categorical',
    shuffle=True)

val_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rescale=1./255
)

valdata = val_datagen.flow_from_directory(
    directory=val_dir, 
    target_size=(224,224), 
    color_mode="rgb", 
    class_mode='categorical',
    shuffle=False)

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rescale=1./255
)

testdata = test_datagen.flow_from_directory(
    directory=test_dir, 
    target_size=(224,224), 
    color_mode="rgb", 
    class_mode='categorical',
    shuffle=False)
# Out:
# Found 7381 images belonging to 10 classes.
# Found 2466 images belonging to 10 classes.
# Found 2464 images belonging to 10 classes.

# %%
print("Informasi Data Training:")
print(f"Jumlah sampel: {traindata.samples}")
print(f"Kelas: {traindata.class_indices}")
print(f"Shape gambar: {traindata.image_shape}")
print(f"Mode warna: {traindata.color_mode}")

print("\nInformasi Data Validasi:")
print(f"Jumlah sampel: {valdata.samples}")
print(f"Kelas: {valdata.class_indices}")
print(f"Shape gambar: {valdata.image_shape}")
print(f"Mode warna: {valdata.color_mode}")

print("\nInformasi Data Test:")
print(f"Jumlah sampel: {testdata.samples}")
print(f"Kelas: {testdata.class_indices}")
print(f"Shape gambar: {testdata.image_shape}")
print(f"Mode warna: {testdata.color_mode}")
# Out:
# Informasi Data Training:
# Jumlah sampel: 7381
# Kelas: {'bathroom': 0, 'bedroom': 1, 'dining': 2, 'gaming': 3, 'kitchen': 4, 'laundry': 5, 'living': 6, 'office': 7, 'terrace': 8, 'yard': 9}
# Shape gambar: (224, 224, 3)
# Mode warna: rgb
#
# Informasi Data Validasi:
# Jumlah sampel: 2466
# Kelas: {'bathroom': 0, 'bedroom': 1, 'dining': 2, 'gaming': 3, 'kitchen': 4, 'laundry': 5, 'living': 6, 'office': 7, 'terrace': 8, 'yard': 9}
# Shape gambar: (224, 224, 3)
# Mode warna: rgb
#
# Informasi Data Test:
# Jumlah sampel: 2464
# Kelas: {'bathroom': 0, 'bedroom': 1, 'dining': 2, 'gaming': 3, 'kitchen': 4, 'laundry': 5, 'living': 6, 'office': 7, 'terrace': 8, 'yard': 9}
# Shape gambar: (224, 224, 3)
# Mode warna: rgb

# %% [markdown]
# ### MODELING

# %%
from tensorflow.keras.applications import MobileNetV3Small

base_model = MobileNetV3Small(input_shape = (224, 224, 3), include_top = False, weights = 'imagenet')

# %%
# Freeze layers except the last 8 layers
for layer in base_model.layers[:-8]:
    layer.trainable = False

# %%
# Check if GPU is available
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    # Set memory growth for GPU
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# Physical devices cannot be modified after being initialized

# %%
from tensorflow import keras
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from keras.regularizers import l2
import tensorflow as tf


model = Sequential()
model.add(Input(shape=(224, 224, 3)))
model.add(base_model)
model.add(Conv2D(512, (3, 3), activation='elu'))
model.add(Conv2D(256, (3, 3), activation='elu'))
model.add(GlobalAveragePooling2D())
model.add(Dense(1024, activation='elu'))
model.add(Dense(512, activation='elu'))
model.add(Dense(len(categories), activation='softmax'))


model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ MobilenetV3small (Functional)   │ (None, 7, 7, 576)      │       939,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 5, 5, 512)      │     2,654,720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 3, 3, 256)      │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │       263,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,566,842 (21.24 MB)
#  Trainable params: 4,739,658 (18.08 MB)
#  Non-trainable params: 827,184 (3.16 MB)

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

device_name = tf.test.gpu_device_name()
modelpath = './output/bestmodel.keras'

# Function to compile and train the model with given parameters
def compile_and_train(model, optimizer, learning_rate, batch_size, modelpath, traindata, valdata):
    with tf.device(device_name):
        if optimizer == 'adam':
            opt = Adam(learning_rate=learning_rate)
        elif optimizer == 'sgd':
            opt = SGD(learning_rate=learning_rate, momentum=0.9)
        elif optimizer == 'rmsprop':
            opt = RMSprop(learning_rate=learning_rate)

        model.compile(
            optimizer=opt,
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )

        early_stopping_acc = EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True, mode='max')
        early_stopping_loss = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, mode='min')
        reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=4, min_lr=0.000005, verbose=1)
        checkpoint = ModelCheckpoint(modelpath, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)

        history = model.fit(
            x=traindata, 
            validation_data=valdata, 
            epochs=200, 
            batch_size=batch_size, 
            callbacks=[early_stopping_acc, early_stopping_loss, reduce_lr, checkpoint]
        )
        return history

# Define the combinations
combinations = [
    {'optimizer': 'adam', 'learning_rate': 0.001, 'batch_size': 32},
    {'optimizer': 'adam', 'learning_rate': 0.0001, 'batch_size': 64},
    {'optimizer': 'sgd', 'learning_rate': 0.01, 'batch_size': 32},
    {'optimizer': 'sgd', 'learning_rate': 0.001, 'batch_size': 64},
    {'optimizer': 'rmsprop', 'learning_rate': 0.001, 'batch_size': 32},
    {'optimizer': 'rmsprop', 'learning_rate': 0.0001, 'batch_size': 64},
]

# List to store evaluation results
results = []

# Loop through combinations and train model
for combo in combinations:
    print(f"Training with optimizer={combo['optimizer']}, learning_rate={combo['learning_rate']}, batch_size={combo['batch_size']}")
    history = compile_and_train(model, combo['optimizer'], combo['learning_rate'], combo['batch_size'], modelpath, traindata, valdata)
    
    # Evaluate model on test data
    test_loss, test_acc = model.evaluate(testdata)
    print(f'Test Loss: {test_loss:.4f}')
    print(f'Test Accuracy: {test_acc * 100:.2f}%')
    
    # Store the results
    results.append({
        'optimizer': combo['optimizer'],
        'learning_rate': combo['learning_rate'],
        'batch_size': combo['batch_size'],
        'test_loss': test_loss,
        'test_acc': test_acc
    })

# Print all results for comparison
for result in results:
    print(f"Optimizer: {result['optimizer']}, Learning Rate: {result['learning_rate']}, Batch Size: {result['batch_size']}")
    print(f"Test Loss: {result['test_loss']:.4f}, Test Accuracy: {result['test_acc'] * 100:.2f}%\n")
# Out:
# Training with optimizer=adam, learning_rate=0.001, batch_size=32
# Epoch 1/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.2608 - loss: 2.0709
# Epoch 1: val_accuracy improved from -inf to 0.13666, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 111s 429ms/step - accuracy: 0.2607 - loss: 2.0708 - val_accuracy: 0.1367 - val_loss: 2.5320 - learning_rate: 0.0010
# Epoch 2/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.2563 - loss: 2.0733
# Epoch 2: val_accuracy improved from 0.13666 to 0.16342, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 389ms/step - accuracy: 0.2564 - loss: 2.0732 - val_accuracy: 0.1634 - val_loss: 2.4697 - learning_rate: 0.0010
# Epoch 3/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.2777 - loss: 2.0382
# Epoch 3: val_accuracy did not improve from 0.16342
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 384ms/step - accuracy: 0.2777 - loss: 2.0381 - val_accuracy: 0.1371 - val_loss: 2.4680 - learning_rate: 0.0010
# Epoch 4/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.2714 - loss: 2.0357
# Epoch 4: val_accuracy did not improve from 0.16342
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 142s 384ms/step - accuracy: 0.2714 - loss: 2.0356 - val_accuracy: 0.1602 - val_loss: 2.8213 - learning_rate: 0.0010
# Epoch 5/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.2874 - loss: 2.0118
# Epoch 5: val_accuracy did not improve from 0.16342
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 383ms/step - accuracy: 0.2873 - loss: 2.0119 - val_accuracy: 0.1225 - val_loss: 2.7719 - learning_rate: 0.0010
# Epoch 6/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.2890 - loss: 1.9970
# Epoch 6: val_accuracy improved from 0.16342 to 0.16586, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 386ms/step - accuracy: 0.2890 - loss: 1.9970 - val_accuracy: 0.1659 - val_loss: 2.5651 - learning_rate: 0.0010
# Epoch 7/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.2763 - loss: 1.9980
# Epoch 7: val_accuracy did not improve from 0.16586
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 385ms/step - accuracy: 0.2764 - loss: 1.9980 - val_accuracy: 0.1217 - val_loss: 3.6679 - learning_rate: 0.0010
# Epoch 8/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.2732 - loss: 2.0679
# Epoch 8: val_accuracy did not improve from 0.16586
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 385ms/step - accuracy: 0.2733 - loss: 2.0675 - val_accuracy: 0.1212 - val_loss: 2.5309 - learning_rate: 0.0010
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.1122 - loss: 2.6001
# Test Loss: 2.4364
# Test Accuracy: 13.68%
# Training with optimizer=adam, learning_rate=0.0001, batch_size=64
# Epoch 1/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.3094 - loss: 1.9190
# Epoch 1: val_accuracy improved from -inf to 0.22263, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 110s 424ms/step - accuracy: 0.3095 - loss: 1.9190 - val_accuracy: 0.2226 - val_loss: 2.3214 - learning_rate: 1.0000e-04
# Epoch 2/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.3249 - loss: 1.9104
# Epoch 2: val_accuracy did not improve from 0.22263
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 388ms/step - accuracy: 0.3249 - loss: 1.9104 - val_accuracy: 0.1987 - val_loss: 2.3459 - learning_rate: 1.0000e-04
# Epoch 3/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.3261 - loss: 1.9087
# Epoch 3: val_accuracy did not improve from 0.22263
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.3261 - loss: 1.9087 - val_accuracy: 0.2101 - val_loss: 2.3668 - learning_rate: 1.0000e-04
# Epoch 4/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.3227 - loss: 1.8845
# Epoch 4: val_accuracy improved from 0.22263 to 0.24818, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 390ms/step - accuracy: 0.3227 - loss: 1.8846 - val_accuracy: 0.2482 - val_loss: 2.2206 - learning_rate: 1.0000e-04
# Epoch 5/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.3193 - loss: 1.9047
# Epoch 5: val_accuracy improved from 0.24818 to 0.26683, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.3193 - loss: 1.9046 - val_accuracy: 0.2668 - val_loss: 2.1672 - learning_rate: 1.0000e-04
# Epoch 6/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.3317 - loss: 1.8764
# Epoch 6: val_accuracy improved from 0.26683 to 0.27088, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 142s 388ms/step - accuracy: 0.3317 - loss: 1.8764 - val_accuracy: 0.2709 - val_loss: 2.1661 - learning_rate: 1.0000e-04
# Epoch 7/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.3396 - loss: 1.8566
# Epoch 7: val_accuracy did not improve from 0.27088
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 383ms/step - accuracy: 0.3396 - loss: 1.8567 - val_accuracy: 0.2676 - val_loss: 2.2487 - learning_rate: 1.0000e-04
# Epoch 8/200
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.3386 - loss: 1.8681
# Epoch 8: val_accuracy did not improve from 0.27088
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 383ms/step - accuracy: 0.3386 - loss: 1.8681 - val_accuracy: 0.2547 - val_loss: 2.2408 - learning_rate: 1.0000e-04
# Epoch 9/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.3195 - loss: 1.8691
# Epoch 9: val_accuracy improved from 0.27088 to 0.29481, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.3196 - loss: 1.8691 - val_accuracy: 0.2948 - val_loss: 2.1094 - learning_rate: 1.0000e-04
# Epoch 10/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.3293 - loss: 1.8786
# Epoch 10: val_accuracy improved from 0.29481 to 0.29886, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.3293 - loss: 1.8785 - val_accuracy: 0.2989 - val_loss: 2.0625 - learning_rate: 1.0000e-04
# Epoch 11/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.3432 - loss: 1.8611
# Epoch 11: val_accuracy did not improve from 0.29886
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 385ms/step - accuracy: 0.3432 - loss: 1.8612 - val_accuracy: 0.2697 - val_loss: 2.2366 - learning_rate: 1.0000e-04
# Epoch 12/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.3413 - loss: 1.8447
# Epoch 12: val_accuracy did not improve from 0.29886
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 385ms/step - accuracy: 0.3413 - loss: 1.8448 - val_accuracy: 0.2753 - val_loss: 2.2043 - learning_rate: 1.0000e-04
# Epoch 13/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.3292 - loss: 1.8854
# Epoch 13: val_accuracy did not improve from 0.29886
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 384ms/step - accuracy: 0.3293 - loss: 1.8852 - val_accuracy: 0.2952 - val_loss: 2.0447 - learning_rate: 1.0000e-04
# Epoch 14/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.3369 - loss: 1.8712
# Epoch 14: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 14: val_accuracy did not improve from 0.29886
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 384ms/step - accuracy: 0.3369 - loss: 1.8711 - val_accuracy: 0.2725 - val_loss: 2.2199 - learning_rate: 1.0000e-04
# Epoch 15/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.3345 - loss: 1.8625
# Epoch 15: val_accuracy improved from 0.29886 to 0.29968, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.3346 - loss: 1.8623 - val_accuracy: 0.2997 - val_loss: 2.0539 - learning_rate: 1.0000e-05
# Epoch 16/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.3524 - loss: 1.8226
# Epoch 16: val_accuracy improved from 0.29968 to 0.32603, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 384ms/step - accuracy: 0.3524 - loss: 1.8227 - val_accuracy: 0.3260 - val_loss: 1.9329 - learning_rate: 1.0000e-05
# Epoch 17/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.3558 - loss: 1.8211
# Epoch 17: val_accuracy improved from 0.32603 to 0.32806, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.3558 - loss: 1.8211 - val_accuracy: 0.3281 - val_loss: 1.9092 - learning_rate: 1.0000e-05
# Epoch 18/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.3478 - loss: 1.8461
# Epoch 18: val_accuracy improved from 0.32806 to 0.34347, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 389ms/step - accuracy: 0.3478 - loss: 1.8460 - val_accuracy: 0.3435 - val_loss: 1.8591 - learning_rate: 1.0000e-05
# Epoch 19/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.3410 - loss: 1.8342
# Epoch 19: val_accuracy improved from 0.34347 to 0.35199, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 393ms/step - accuracy: 0.3411 - loss: 1.8342 - val_accuracy: 0.3520 - val_loss: 1.8413 - learning_rate: 1.0000e-05
# Epoch 20/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.3501 - loss: 1.8212
# Epoch 20: val_accuracy did not improve from 0.35199
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 388ms/step - accuracy: 0.3501 - loss: 1.8212 - val_accuracy: 0.3483 - val_loss: 1.8324 - learning_rate: 1.0000e-05
# Epoch 21/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.3586 - loss: 1.8317
# Epoch 21: val_accuracy improved from 0.35199 to 0.35361, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 386ms/step - accuracy: 0.3586 - loss: 1.8316 - val_accuracy: 0.3536 - val_loss: 1.8213 - learning_rate: 1.0000e-05
# Epoch 22/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.3563 - loss: 1.8196
# Epoch 22: val_accuracy did not improve from 0.35361
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 385ms/step - accuracy: 0.3563 - loss: 1.8196 - val_accuracy: 0.3487 - val_loss: 1.8215 - learning_rate: 1.0000e-05
# Epoch 23/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.3474 - loss: 1.8339
# Epoch 23: val_accuracy did not improve from 0.35361
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 383ms/step - accuracy: 0.3475 - loss: 1.8338 - val_accuracy: 0.3528 - val_loss: 1.8214 - learning_rate: 1.0000e-05
# Epoch 24/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.3523 - loss: 1.8261
# Epoch 24: val_accuracy did not improve from 0.35361
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 383ms/step - accuracy: 0.3524 - loss: 1.8260 - val_accuracy: 0.3520 - val_loss: 1.8178 - learning_rate: 1.0000e-05
# Epoch 25/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.3503 - loss: 1.8277
# Epoch 25: ReduceLROnPlateau reducing learning rate to 5e-06.
#
# Epoch 25: val_accuracy did not improve from 0.35361
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 384ms/step - accuracy: 0.3503 - loss: 1.8276 - val_accuracy: 0.3528 - val_loss: 1.8154 - learning_rate: 1.0000e-05
# Epoch 26/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.3532 - loss: 1.8228
# Epoch 26: val_accuracy did not improve from 0.35361
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 384ms/step - accuracy: 0.3532 - loss: 1.8228 - val_accuracy: 0.3516 - val_loss: 1.8101 - learning_rate: 5.0000e-06
# Epoch 27/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.3494 - loss: 1.8216
# Epoch 27: val_accuracy did not improve from 0.35361
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.3494 - loss: 1.8216 - val_accuracy: 0.3508 - val_loss: 1.8110 - learning_rate: 5.0000e-06
# Epoch 28/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.3550 - loss: 1.8252
# Epoch 28: val_accuracy did not improve from 0.35361
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 383ms/step - accuracy: 0.3549 - loss: 1.8253 - val_accuracy: 0.3516 - val_loss: 1.8081 - learning_rate: 5.0000e-06
# Epoch 29/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.3540 - loss: 1.8154
# Epoch 29: val_accuracy did not improve from 0.35361
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 383ms/step - accuracy: 0.3540 - loss: 1.8154 - val_accuracy: 0.3520 - val_loss: 1.8080 - learning_rate: 5.0000e-06
# Epoch 30/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.3457 - loss: 1.8342
# Epoch 30: val_accuracy improved from 0.35361 to 0.35564, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 388ms/step - accuracy: 0.3458 - loss: 1.8341 - val_accuracy: 0.3556 - val_loss: 1.8068 - learning_rate: 5.0000e-06
# Epoch 31/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.3478 - loss: 1.8271
# Epoch 31: val_accuracy did not improve from 0.35564
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 385ms/step - accuracy: 0.3479 - loss: 1.8270 - val_accuracy: 0.3504 - val_loss: 1.8078 - learning_rate: 5.0000e-06
# Epoch 32/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.3583 - loss: 1.8050
# Epoch 32: val_accuracy did not improve from 0.35564
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.3583 - loss: 1.8051 - val_accuracy: 0.3544 - val_loss: 1.8089 - learning_rate: 5.0000e-06
# Epoch 33/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.3527 - loss: 1.8083
# Epoch 33: val_accuracy did not improve from 0.35564
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 385ms/step - accuracy: 0.3527 - loss: 1.8084 - val_accuracy: 0.3532 - val_loss: 1.8097 - learning_rate: 5.0000e-06
# Epoch 34/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.3609 - loss: 1.8126
# Epoch 34: val_accuracy did not improve from 0.35564
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 382ms/step - accuracy: 0.3608 - loss: 1.8126 - val_accuracy: 0.3540 - val_loss: 1.8091 - learning_rate: 5.0000e-06
# Epoch 35/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.3660 - loss: 1.8050
# Epoch 35: val_accuracy did not improve from 0.35564
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.3659 - loss: 1.8051 - val_accuracy: 0.3544 - val_loss: 1.8106 - learning_rate: 5.0000e-06
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.2898 - loss: 2.0082
# Test Loss: 1.7932
# Test Accuracy: 35.59%
# Training with optimizer=sgd, learning_rate=0.01, batch_size=32
# Epoch 1/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.1690 - loss: 2.6292
# Epoch 1: val_accuracy improved from -inf to 0.12936, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 110s 426ms/step - accuracy: 0.1690 - loss: 2.6294 - val_accuracy: 0.1294 - val_loss: 1486.8761 - learning_rate: 0.0100
# Epoch 2/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.2103 - loss: 2.4809
# Epoch 2: val_accuracy improved from 0.12936 to 0.22141, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 388ms/step - accuracy: 0.2103 - loss: 2.4811 - val_accuracy: 0.2214 - val_loss: 2.4673 - learning_rate: 0.0100
# Epoch 3/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.2097 - loss: 2.5007
# Epoch 3: val_accuracy did not improve from 0.22141
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 384ms/step - accuracy: 0.2097 - loss: 2.5003 - val_accuracy: 0.1298 - val_loss: 313.0613 - learning_rate: 0.0100
# Epoch 4/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.2275 - loss: 2.4680
# Epoch 4: val_accuracy did not improve from 0.22141
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 383ms/step - accuracy: 0.2275 - loss: 2.4686 - val_accuracy: 0.2206 - val_loss: 2.6582 - learning_rate: 0.0100
# Epoch 5/200
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.2381 - loss: 2.3741
# Epoch 5: val_accuracy did not improve from 0.22141
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 382ms/step - accuracy: 0.2381 - loss: 2.3742 - val_accuracy: 0.1784 - val_loss: 3.0827 - learning_rate: 0.0100
# Epoch 6/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.2192 - loss: 2.6035
# Epoch 6: val_accuracy improved from 0.22141 to 0.22709, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 385ms/step - accuracy: 0.2192 - loss: 2.6024 - val_accuracy: 0.2271 - val_loss: 2.6774 - learning_rate: 0.0100
# Epoch 7/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.2258 - loss: 2.3840
# Epoch 7: val_accuracy did not improve from 0.22709
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 383ms/step - accuracy: 0.2259 - loss: 2.3835 - val_accuracy: 0.1975 - val_loss: 3.3952 - learning_rate: 0.0100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.1043 - loss: 3.0910
# Test Loss: 2.4843
# Test Accuracy: 22.04%
# Training with optimizer=sgd, learning_rate=0.001, batch_size=64
# Epoch 1/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.2890 - loss: 2.0365
# Epoch 1: val_accuracy improved from -inf to 0.30819, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 109s 423ms/step - accuracy: 0.2891 - loss: 2.0361 - val_accuracy: 0.3082 - val_loss: 1.9127 - learning_rate: 0.0010
# Epoch 2/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.3119 - loss: 1.9491
# Epoch 2: val_accuracy improved from 0.30819 to 0.31630, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 383ms/step - accuracy: 0.3118 - loss: 1.9492 - val_accuracy: 0.3163 - val_loss: 1.9381 - learning_rate: 0.0010
# Epoch 3/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.3058 - loss: 1.9443
# Epoch 3: val_accuracy did not improve from 0.31630
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 383ms/step - accuracy: 0.3059 - loss: 1.9443 - val_accuracy: 0.2956 - val_loss: 1.9107 - learning_rate: 0.0010
# Epoch 4/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.3152 - loss: 1.9401
# Epoch 4: val_accuracy did not improve from 0.31630
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 90s 380ms/step - accuracy: 0.3151 - loss: 1.9402 - val_accuracy: 0.2733 - val_loss: 1.9367 - learning_rate: 0.0010
# Epoch 5/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.3059 - loss: 1.9364
# Epoch 5: val_accuracy did not improve from 0.31630
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 383ms/step - accuracy: 0.3060 - loss: 1.9364 - val_accuracy: 0.3070 - val_loss: 1.9263 - learning_rate: 0.0010
# Epoch 6/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.3193 - loss: 1.9197
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 6: val_accuracy did not improve from 0.31630
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 384ms/step - accuracy: 0.3192 - loss: 1.9197 - val_accuracy: 0.2879 - val_loss: 1.9548 - learning_rate: 0.0010
# Epoch 7/200
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.3139 - loss: 1.9180
# Epoch 7: val_accuracy improved from 0.31630 to 0.33009, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.3139 - loss: 1.9179 - val_accuracy: 0.3301 - val_loss: 1.8800 - learning_rate: 1.0000e-04
# Epoch 8/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.3380 - loss: 1.8829
# Epoch 8: val_accuracy did not improve from 0.33009
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 385ms/step - accuracy: 0.3379 - loss: 1.8829 - val_accuracy: 0.3301 - val_loss: 1.8848 - learning_rate: 1.0000e-04
# Epoch 9/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.3352 - loss: 1.8770
# Epoch 9: val_accuracy improved from 0.33009 to 0.33293, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.3352 - loss: 1.8770 - val_accuracy: 0.3329 - val_loss: 1.8764 - learning_rate: 1.0000e-04
# Epoch 10/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.3201 - loss: 1.8937
# Epoch 10: val_accuracy improved from 0.33293 to 0.33698, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 388ms/step - accuracy: 0.3202 - loss: 1.8935 - val_accuracy: 0.3370 - val_loss: 1.8634 - learning_rate: 1.0000e-04
# Epoch 11/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.3376 - loss: 1.8709
# Epoch 11: val_accuracy improved from 0.33698 to 0.33779, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.3375 - loss: 1.8709 - val_accuracy: 0.3378 - val_loss: 1.8610 - learning_rate: 1.0000e-04
# Epoch 12/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.3412 - loss: 1.8591
# Epoch 12: val_accuracy improved from 0.33779 to 0.33942, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.3412 - loss: 1.8591 - val_accuracy: 0.3394 - val_loss: 1.8578 - learning_rate: 1.0000e-04
# Epoch 13/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.3256 - loss: 1.8875
# Epoch 13: val_accuracy did not improve from 0.33942
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.3256 - loss: 1.8875 - val_accuracy: 0.3378 - val_loss: 1.8566 - learning_rate: 1.0000e-04
# Epoch 14/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.3262 - loss: 1.8925
# Epoch 14: val_accuracy improved from 0.33942 to 0.34509, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.3263 - loss: 1.8923 - val_accuracy: 0.3451 - val_loss: 1.8584 - learning_rate: 1.0000e-04
# Epoch 15/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.3367 - loss: 1.8732
# Epoch 15: val_accuracy improved from 0.34509 to 0.34874, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 386ms/step - accuracy: 0.3367 - loss: 1.8731 - val_accuracy: 0.3487 - val_loss: 1.8513 - learning_rate: 1.0000e-04
# Epoch 16/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.3417 - loss: 1.8656
# Epoch 16: val_accuracy did not improve from 0.34874
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 383ms/step - accuracy: 0.3416 - loss: 1.8657 - val_accuracy: 0.3362 - val_loss: 1.8523 - learning_rate: 1.0000e-04
# Epoch 17/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.3344 - loss: 1.8671
# Epoch 17: val_accuracy did not improve from 0.34874
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 386ms/step - accuracy: 0.3344 - loss: 1.8672 - val_accuracy: 0.3443 - val_loss: 1.8420 - learning_rate: 1.0000e-04
# Epoch 18/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.3392 - loss: 1.8598
# Epoch 18: val_accuracy did not improve from 0.34874
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 384ms/step - accuracy: 0.3391 - loss: 1.8599 - val_accuracy: 0.3483 - val_loss: 1.8434 - learning_rate: 1.0000e-04
# Epoch 19/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.3422 - loss: 1.8636
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 19: val_accuracy did not improve from 0.34874
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 90s 381ms/step - accuracy: 0.3422 - loss: 1.8636 - val_accuracy: 0.3463 - val_loss: 1.8354 - learning_rate: 1.0000e-04
# Epoch 20/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.3373 - loss: 1.8844
# Epoch 20: val_accuracy did not improve from 0.34874
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 90s 381ms/step - accuracy: 0.3373 - loss: 1.8843 - val_accuracy: 0.3471 - val_loss: 1.8375 - learning_rate: 1.0000e-05
# Epoch 21/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.3439 - loss: 1.8535
# Epoch 21: val_accuracy did not improve from 0.34874
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 143s 386ms/step - accuracy: 0.3439 - loss: 1.8535 - val_accuracy: 0.3483 - val_loss: 1.8383 - learning_rate: 1.0000e-05
# Epoch 22/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.3375 - loss: 1.8694
# Epoch 22: val_accuracy did not improve from 0.34874
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 382ms/step - accuracy: 0.3376 - loss: 1.8692 - val_accuracy: 0.3483 - val_loss: 1.8372 - learning_rate: 1.0000e-05
# Epoch 23/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.3492 - loss: 1.8476
# Epoch 23: val_accuracy improved from 0.34874 to 0.35036, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 384ms/step - accuracy: 0.3491 - loss: 1.8477 - val_accuracy: 0.3504 - val_loss: 1.8362 - learning_rate: 1.0000e-05
# Epoch 24/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.3377 - loss: 1.8617
# Epoch 24: val_accuracy did not improve from 0.35036
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 381ms/step - accuracy: 0.3377 - loss: 1.8617 - val_accuracy: 0.3479 - val_loss: 1.8357 - learning_rate: 1.0000e-05
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.2769 - loss: 2.0113
# Test Loss: 1.8231
# Test Accuracy: 34.17%
# Training with optimizer=rmsprop, learning_rate=0.001, batch_size=32
# Epoch 1/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.1864 - loss: 2.7305
# Epoch 1: val_accuracy improved from -inf to 0.15856, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 110s 424ms/step - accuracy: 0.1865 - loss: 2.7272 - val_accuracy: 0.1586 - val_loss: 2.4060 - learning_rate: 0.0010
# Epoch 2/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.2251 - loss: 2.1824
# Epoch 2: val_accuracy improved from 0.15856 to 0.16018, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 383ms/step - accuracy: 0.2252 - loss: 2.1824 - val_accuracy: 0.1602 - val_loss: 2.4438 - learning_rate: 0.0010
# Epoch 3/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.2310 - loss: 2.1595
# Epoch 3: val_accuracy improved from 0.16018 to 0.19951, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 383ms/step - accuracy: 0.2311 - loss: 2.1593 - val_accuracy: 0.1995 - val_loss: 2.2154 - learning_rate: 0.0010
# Epoch 4/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.2360 - loss: 2.1245
# Epoch 4: val_accuracy did not improve from 0.19951
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 90s 380ms/step - accuracy: 0.2361 - loss: 2.1244 - val_accuracy: 0.1431 - val_loss: 2.5925 - learning_rate: 0.0010
# Epoch 5/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.2566 - loss: 2.0953
# Epoch 5: val_accuracy improved from 0.19951 to 0.21046, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 90s 381ms/step - accuracy: 0.2566 - loss: 2.0952 - val_accuracy: 0.2105 - val_loss: 2.2503 - learning_rate: 0.0010
# Epoch 6/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.2609 - loss: 2.0935
# Epoch 6: val_accuracy did not improve from 0.21046
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 90s 379ms/step - accuracy: 0.2610 - loss: 2.0934 - val_accuracy: 0.1598 - val_loss: 2.3435 - learning_rate: 0.0010
# Epoch 7/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.2668 - loss: 2.0756
# Epoch 7: val_accuracy did not improve from 0.21046
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 142s 379ms/step - accuracy: 0.2669 - loss: 2.0757 - val_accuracy: 0.1407 - val_loss: 2.9369 - learning_rate: 0.0010
# Epoch 8/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.2748 - loss: 2.0434
# Epoch 8: val_accuracy did not improve from 0.21046
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 382ms/step - accuracy: 0.2748 - loss: 2.0434 - val_accuracy: 0.1744 - val_loss: 2.2553 - learning_rate: 0.0010
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.1043 - loss: 2.2513
# Test Loss: 2.1841
# Test Accuracy: 21.23%
# Training with optimizer=rmsprop, learning_rate=0.0001, batch_size=64
# Epoch 1/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.2986 - loss: 1.9415
# Epoch 1: val_accuracy improved from -inf to 0.18856, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 109s 422ms/step - accuracy: 0.2987 - loss: 1.9412 - val_accuracy: 0.1886 - val_loss: 2.2967 - learning_rate: 1.0000e-04
# Epoch 2/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.3279 - loss: 1.8997
# Epoch 2: val_accuracy improved from 0.18856 to 0.20600, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 385ms/step - accuracy: 0.3278 - loss: 1.8997 - val_accuracy: 0.2060 - val_loss: 2.2775 - learning_rate: 1.0000e-04
# Epoch 3/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.3102 - loss: 1.8952
# Epoch 3: val_accuracy improved from 0.20600 to 0.22668, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 383ms/step - accuracy: 0.3103 - loss: 1.8951 - val_accuracy: 0.2267 - val_loss: 2.2287 - learning_rate: 1.0000e-04
# Epoch 4/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.3334 - loss: 1.8738
# Epoch 4: val_accuracy improved from 0.22668 to 0.25669, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 383ms/step - accuracy: 0.3334 - loss: 1.8738 - val_accuracy: 0.2567 - val_loss: 2.0650 - learning_rate: 1.0000e-04
# Epoch 5/200
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.3382 - loss: 1.8599
# Epoch 5: val_accuracy improved from 0.25669 to 0.28183, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 384ms/step - accuracy: 0.3382 - loss: 1.8599 - val_accuracy: 0.2818 - val_loss: 2.0283 - learning_rate: 1.0000e-04
# Epoch 6/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.3396 - loss: 1.8428
# Epoch 6: val_accuracy improved from 0.28183 to 0.30454, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 382ms/step - accuracy: 0.3396 - loss: 1.8430 - val_accuracy: 0.3045 - val_loss: 1.9878 - learning_rate: 1.0000e-04
# Epoch 7/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.3443 - loss: 1.8448
# Epoch 7: val_accuracy improved from 0.30454 to 0.31306, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 385ms/step - accuracy: 0.3442 - loss: 1.8449 - val_accuracy: 0.3131 - val_loss: 1.9518 - learning_rate: 1.0000e-04
# Epoch 8/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.3370 - loss: 1.8677
# Epoch 8: val_accuracy improved from 0.31306 to 0.32238, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 383ms/step - accuracy: 0.3371 - loss: 1.8676 - val_accuracy: 0.3224 - val_loss: 1.9279 - learning_rate: 1.0000e-04
# Epoch 9/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.3419 - loss: 1.8369
# Epoch 9: val_accuracy did not improve from 0.32238
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 383ms/step - accuracy: 0.3419 - loss: 1.8370 - val_accuracy: 0.3195 - val_loss: 1.9518 - learning_rate: 1.0000e-04
# Epoch 10/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.3395 - loss: 1.8479
# Epoch 10: val_accuracy did not improve from 0.32238
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 381ms/step - accuracy: 0.3395 - loss: 1.8479 - val_accuracy: 0.2863 - val_loss: 2.0559 - learning_rate: 1.0000e-04
# Epoch 11/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.3346 - loss: 1.8605
# Epoch 11: val_accuracy did not improve from 0.32238
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 90s 378ms/step - accuracy: 0.3347 - loss: 1.8604 - val_accuracy: 0.3029 - val_loss: 1.9622 - learning_rate: 1.0000e-04
# Epoch 12/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.3598 - loss: 1.8334
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 12: val_accuracy did not improve from 0.32238
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 143s 381ms/step - accuracy: 0.3597 - loss: 1.8334 - val_accuracy: 0.3078 - val_loss: 1.9591 - learning_rate: 1.0000e-04
# Epoch 13/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.3617 - loss: 1.8073
# Epoch 13: val_accuracy improved from 0.32238 to 0.32360, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 383ms/step - accuracy: 0.3616 - loss: 1.8074 - val_accuracy: 0.3236 - val_loss: 1.9040 - learning_rate: 1.0000e-05
# Epoch 14/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.3517 - loss: 1.8476
# Epoch 14: val_accuracy improved from 0.32360 to 0.32685, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 388ms/step - accuracy: 0.3517 - loss: 1.8477 - val_accuracy: 0.3268 - val_loss: 1.8889 - learning_rate: 1.0000e-05
# Epoch 15/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.3617 - loss: 1.8172
# Epoch 15: val_accuracy improved from 0.32685 to 0.32928, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.3616 - loss: 1.8171 - val_accuracy: 0.3293 - val_loss: 1.8632 - learning_rate: 1.0000e-05
# Epoch 16/200
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.3464 - loss: 1.8319
# Epoch 16: val_accuracy improved from 0.32928 to 0.36010, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.3464 - loss: 1.8318 - val_accuracy: 0.3601 - val_loss: 1.8176 - learning_rate: 1.0000e-05
# Epoch 17/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.3485 - loss: 1.8147
# Epoch 17: val_accuracy did not improve from 0.36010
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 385ms/step - accuracy: 0.3486 - loss: 1.8147 - val_accuracy: 0.3500 - val_loss: 1.8358 - learning_rate: 1.0000e-05
# Epoch 18/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.3599 - loss: 1.7988
# Epoch 18: val_accuracy did not improve from 0.36010
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 382ms/step - accuracy: 0.3599 - loss: 1.7990 - val_accuracy: 0.3496 - val_loss: 1.8220 - learning_rate: 1.0000e-05
# Epoch 19/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.3570 - loss: 1.8070
# Epoch 19: val_accuracy did not improve from 0.36010
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 90s 381ms/step - accuracy: 0.3570 - loss: 1.8070 - val_accuracy: 0.3556 - val_loss: 1.8104 - learning_rate: 1.0000e-05
# Epoch 20/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.3687 - loss: 1.8042
# Epoch 20: ReduceLROnPlateau reducing learning rate to 5e-06.
#
# Epoch 20: val_accuracy did not improve from 0.36010
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 382ms/step - accuracy: 0.3686 - loss: 1.8043 - val_accuracy: 0.3577 - val_loss: 1.8042 - learning_rate: 1.0000e-05
# Epoch 21/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.3603 - loss: 1.8208
# Epoch 21: val_accuracy did not improve from 0.36010
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 382ms/step - accuracy: 0.3603 - loss: 1.8207 - val_accuracy: 0.3593 - val_loss: 1.8072 - learning_rate: 5.0000e-06
# Epoch 22/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.3482 - loss: 1.8332
# Epoch 22: val_accuracy did not improve from 0.36010
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 382ms/step - accuracy: 0.3482 - loss: 1.8330 - val_accuracy: 0.3589 - val_loss: 1.8005 - learning_rate: 5.0000e-06
# Epoch 23/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.3549 - loss: 1.8164
# Epoch 23: val_accuracy did not improve from 0.36010
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 386ms/step - accuracy: 0.3549 - loss: 1.8163 - val_accuracy: 0.3581 - val_loss: 1.7958 - learning_rate: 5.0000e-06
# Epoch 24/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.3615 - loss: 1.8042
# Epoch 24: val_accuracy did not improve from 0.36010
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 384ms/step - accuracy: 0.3615 - loss: 1.8043 - val_accuracy: 0.3585 - val_loss: 1.8032 - learning_rate: 5.0000e-06
# Epoch 25/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.3473 - loss: 1.8155
# Epoch 25: val_accuracy improved from 0.36010 to 0.36050, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 383ms/step - accuracy: 0.3474 - loss: 1.8154 - val_accuracy: 0.3605 - val_loss: 1.7960 - learning_rate: 5.0000e-06
# Epoch 26/200
# 174/231 ━━━━━━━━━━━━━━━━━━━━ 21s 373ms/step - accuracy: 0.3594 - loss: 1.8050

# %%
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau


device_name = tf.test.gpu_device_name()

modelpath = './output/bestmodel.keras'

### train the model
with tf.device(device_name):
    
    optimizer = Adam(learning_rate=0.001)
    
    model.compile(
      optimizer=optimizer,
      loss='categorical_crossentropy',
      metrics=['accuracy'])
    
    # Early stopping for val_accuracy
    early_stopping_acc = EarlyStopping(monitor='val_accuracy', patience=10, 
                                       restore_best_weights=True, mode='max')

    # Early stopping for val_loss
    early_stopping_loss = EarlyStopping(monitor='val_loss', patience=5, 
                                        restore_best_weights=True, mode='min')

    
    # Reduce learning rate when a metric has stopped improving
    reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, 
                                  patience=4, min_lr=0.000001, verbose=1)

    
    # Callback ModelCheckpoint untuk menyimpan bobot terbaik
    checkpoint = ModelCheckpoint(
        modelpath,
        monitor='val_accuracy',
        save_best_only=True,  # Hanya menyimpan bobot terbaik
        mode='max',  # Mode untuk membandingkan nilai metrik (misalnya 'max' untuk akurasi)
        verbose=1  # Menampilkan pesan saat menyimpan
    )

    # Train the model
    history = model.fit(x=traindata, validation_data=valdata, epochs=200, 
                        batch_size=32, callbacks=[early_stopping_acc, early_stopping_loss,
                                                  reduce_lr, checkpoint])
# Out:
# Epoch 1/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.2487 - loss: 2.1440
# Epoch 1: val_accuracy improved from -inf to 0.13585, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 112s 431ms/step - accuracy: 0.2487 - loss: 2.1439 - val_accuracy: 0.1358 - val_loss: 2.5211 - learning_rate: 0.0010
# Epoch 2/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.2384 - loss: 2.1248
# Epoch 2: val_accuracy improved from 0.13585 to 0.15977, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.2385 - loss: 2.1248 - val_accuracy: 0.1598 - val_loss: 2.5417 - learning_rate: 0.0010
# Epoch 3/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.2442 - loss: 2.0929
# Epoch 3: val_accuracy did not improve from 0.15977
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 388ms/step - accuracy: 0.2443 - loss: 2.0928 - val_accuracy: 0.1500 - val_loss: 2.6419 - learning_rate: 0.0010
# Epoch 4/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.2554 - loss: 2.0829
# Epoch 4: val_accuracy improved from 0.15977 to 0.16018, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 389ms/step - accuracy: 0.2554 - loss: 2.0830 - val_accuracy: 0.1602 - val_loss: 2.3891 - learning_rate: 0.0010
# Epoch 5/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.2441 - loss: 2.0831
# Epoch 5: val_accuracy improved from 0.16018 to 0.16586, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 390ms/step - accuracy: 0.2442 - loss: 2.0830 - val_accuracy: 0.1659 - val_loss: 2.2809 - learning_rate: 0.0010
# Epoch 6/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.2645 - loss: 2.0570
# Epoch 6: val_accuracy did not improve from 0.16586
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 386ms/step - accuracy: 0.2646 - loss: 2.0569 - val_accuracy: 0.1594 - val_loss: 2.7278 - learning_rate: 0.0010
# Epoch 7/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.2775 - loss: 2.0225
# Epoch 7: val_accuracy improved from 0.16586 to 0.17802, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 389ms/step - accuracy: 0.2775 - loss: 2.0225 - val_accuracy: 0.1780 - val_loss: 2.3850 - learning_rate: 0.0010
# Epoch 8/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.2491 - loss: 2.0861
# Epoch 8: val_accuracy did not improve from 0.17802
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 385ms/step - accuracy: 0.2491 - loss: 2.0860 - val_accuracy: 0.1549 - val_loss: 2.3346 - learning_rate: 0.0010
# Epoch 9/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.2677 - loss: 2.0420
# Epoch 9: val_accuracy improved from 0.17802 to 0.19059, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 386ms/step - accuracy: 0.2676 - loss: 2.0421 - val_accuracy: 0.1906 - val_loss: 2.4570 - learning_rate: 0.0010
# Epoch 10/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.2835 - loss: 2.0070
# Epoch 10: val_accuracy did not improve from 0.19059
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 91s 385ms/step - accuracy: 0.2835 - loss: 2.0071 - val_accuracy: 0.1618 - val_loss: 2.8125 - learning_rate: 0.0010

# %%
# Evaluasi model pada data test
test_loss, test_acc = model.evaluate(testdata)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_acc * 100:.2f}%')
# Out:
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.1051 - loss: 2.3925
# Test Loss: 2.2523
# Test Accuracy: 18.30%

# %%
# Visualize the model

plt.plot(history.history['accuracy'], marker='o')
plt.plot(history.history['val_accuracy'], marker='o')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='lower right')
plt.show()

# %%
# Visualize the model accuracy including test accuracy
plt.plot(history.history['accuracy'], marker='o')
plt.plot(history.history['val_accuracy'], marker='o')

# Menambahkan test accuracy ke grafik
epochs = range(1, len(history.history['accuracy']) + 1)
plt.plot(epochs, [test_acc] * len(epochs), linestyle='--', marker='o')

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation', 'Test'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'], marker='o')
plt.plot(history.history['val_loss'], marker='o')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

# Prediksi label kelas menggunakan model terhadap data uji
predictions = model.predict(testdata)
predicted_classes = np.argmax(predictions, axis=1)

# Ambil label sebenarnya dari data uji
true_classes = testdata.labels

# Dapatkan nama kelas
class_labels = list(testdata.class_indices.keys())

# Buat classification matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Print classification matrix
print("Classification Matrix:")
print(cm)

# Print classification report
print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))
# Out:
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step
# Classification Matrix:
# [[  0 122  26   0   0   0   0   0   0   0]
#  [  0 175  41   0   0   0   0   0   0   0]
#  [  0  95 140   0   0   0   0   0   0   0]
#  [  0 243  58   0   1   0   0   0   0   0]
#  [  0 157  85   0   0   0   0   0   0   0]
#  [  1 253  64   0   0   0   0   0   0   0]
#  [  0 126 107   0   0   0   0   0   0   0]
#  [  0 174  75   0   0   0   0   0   0   0]
#  [  0  95 147   0   0   0   0   0   0   0]
#  [  0  71 208   0   0   0   0   0   0   0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     bathroom       0.00      0.00      0.00       148
#      bedroom       0.12      0.81      0.20       216
#       dining       0.15      0.60      0.24       235
#       gaming       0.00      0.00      0.00       302
#      kitchen       0.00      0.00      0.00       242
#      laundry       0.00      0.00      0.00       318
#       living       0.00      0.00      0.00       233
#       office       0.00      0.00      0.00       249
#      terrace       0.00      0.00      0.00       242
#         yard       0.00      0.00      0.00       279
#
#     accuracy                           0.13      2464
#    macro avg       0.03      0.14      0.04      2464
# weighted avg       0.02      0.13      0.04      2464
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Accuracy adalah rasio dari jumlah prediksi yang benar (true predictions) dibagi dengan jumlah total instance dalam dataset.

# %% [markdown]
# Precision mengukur seberapa akurat model dalam memprediksi kelas positif. Ini dihitung sebagai rasio dari true positive (TP) dibagi oleh jumlah true positive dan false positive (FP).

# %% [markdown]
#  Recall mengukur seberapa baik model dalam menemukan semua instance yang benar dari kelas yang diinginkan. Ini dihitung sebagai rasio dari true positive (TP) dibagi oleh jumlah true positive dan false negative (FN).

# %% [markdown]
# F1-score adalah rata-rata harmonik dari precision dan recall. Ini memberikan keseimbangan antara precision dan recall.
