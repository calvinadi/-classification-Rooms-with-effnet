# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import random

import glob as gb
import cv2
import matplotlib.pylab as plt
plt.style.use('ggplot')

# %% [markdown]
# ### Dataset source: https://www.kaggle.com/datasets/annielu21/house-rooms

# %%
import warnings

warnings.filterwarnings("ignore", message="All log messages before absl::InitializeLog() is called are written to STDERR")
warnings.filterwarnings("ignore", message="Fallback to op-by-op mode because memset node breaks graph update")

# %%
from sklearn.model_selection import train_test_split
import os
import shutil
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
# Out:
# 2024-06-27 06:10:20.757275: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-27 06:10:20.757333: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-27 06:10:20.758756: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    tf.random.set_seed(random_seed)
    os.environ['PYTHONHASHSEED'] = str(random_seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'

# %%
set_random_seed(42)

# %%
# Path gambar
img_path = '/kaggle/input/processed-room-image/clahe_processed_images'

input_dir = 'images'
output_dir = 'output'

# Membuat folder output jika belum ada
os.makedirs(output_dir, exist_ok=True)

# %%
# Membuat Folder Kategori
categories = ['bathroom', 'bedroom', 'dining', 'gaming', 
              'kitchen','laundry','living', 'office',
             'terrace', 'yard']

for category in categories:
    category_dir = os.path.join(output_dir, category)
    os.makedirs(category_dir, exist_ok=True)

# %%
# Memindahkan file ke folder yang dipilih
for root, dirs, files in os.walk(img_path):
    for file in files:
        category = os.path.basename(root)
        if category in categories:
            source_file = os.path.join(root, file)
            destination_dir = os.path.join(output_dir, category)
            shutil.copy(source_file, destination_dir)

# Menampilkan jumlah file dalam setiap kategori
for category in categories:
    category_dir = os.path.join(output_dir, category)
    num_files = len(os.listdir(category_dir))
    print(f"Total {category} files: {num_files}")
# Out:
# Total bathroom files: 740
# Total bedroom files: 1083
# Total dining files: 1178
# Total gaming files: 1511
# Total kitchen files: 1208
# Total laundry files: 1589
# Total living files: 1164
# Total office files: 1241
# Total terrace files: 1210
# Total yard files: 1398

# %%
# Buat folder train, validation, dan test
train_dir = os.path.join(output_dir, "train")
val_dir = os.path.join(output_dir, "validation")
test_dir = os.path.join(output_dir, "test")

if os.path.exists(train_dir):
    shutil.rmtree(train_dir)
if os.path.exists(val_dir):
    shutil.rmtree(val_dir)
if os.path.exists(test_dir):
    shutil.rmtree(test_dir)
    
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# Split data menjadi train, validation, dan test
for category in categories:
    category_dir = os.path.join(output_dir, category)
    images = os.listdir(category_dir)
    
    # Pembagian train, validation, test (70%, 15%, 15%)
    train_images, val_test_images = train_test_split(images, test_size=0.4, random_state=42)
    val_images, test_images = train_test_split(val_test_images, test_size=0.5, random_state=42)
    
    # Pindahkan gambar-gambar ke dalam folder train, validation, dan test
    for img in train_images:
        target_dir = os.path.join(train_dir, category)
        os.makedirs(target_dir, exist_ok=True)
        shutil.move(os.path.join(category_dir, img), os.path.join(target_dir, img))

    for img in val_images:
        target_dir = os.path.join(val_dir, category)
        os.makedirs(target_dir, exist_ok=True)
        shutil.move(os.path.join(category_dir, img), os.path.join(target_dir, img))
        
    for img in test_images:
        target_dir = os.path.join(test_dir, category)
        os.makedirs(target_dir, exist_ok=True)
        shutil.move(os.path.join(category_dir, img), os.path.join(target_dir, img))

# %%
# Cetak jumlah gambar dalam folder train
print("\nJumlah Gambar dalam Folder Train:")
for category in categories:
    train_category_dir = os.path.join(train_dir, category)
    num_train_images = len(os.listdir(train_category_dir))
    print(f"{category}: {num_train_images} gambar")

# Cetak jumlah gambar dalam folder validation
print("\nJumlah Gambar dalam Folder Validation:")
for category in categories:
    val_category_dir = os.path.join(val_dir, category)
    num_val_images = len(os.listdir(val_category_dir))
    print(f"{category}: {num_val_images} gambar")

# Cetak jumlah gambar dalam folder test
print("\nJumlah Gambar dalam Folder Test:")
for category in categories:
    test_category_dir = os.path.join(test_dir, category)
    num_test_images = len(os.listdir(test_category_dir))
    print(f"{category}: {num_test_images} gambar")
# Out:
# Jumlah Gambar dalam Folder Train:
# bathroom: 444 gambar
# bedroom: 649 gambar
# dining: 706 gambar
# gaming: 906 gambar
# kitchen: 724 gambar
# laundry: 953 gambar
# living: 698 gambar
# office: 744 gambar
# terrace: 726 gambar
# yard: 838 gambar
#
# Jumlah Gambar dalam Folder Validation:
# bathroom: 148 gambar
# bedroom: 217 gambar
# dining: 236 gambar
# gaming: 302 gambar
# kitchen: 242 gambar
# laundry: 318 gambar
# living: 233 gambar
# office: 248 gambar
# terrace: 242 gambar
# yard: 280 gambar
#
# Jumlah Gambar dalam Folder Test:
# bathroom: 148 gambar
# bedroom: 217 gambar
# dining: 236 gambar
# gaming: 303 gambar
# kitchen: 242 gambar
# laundry: 318 gambar
# living: 233 gambar
# office: 249 gambar
# terrace: 242 gambar
# yard: 280 gambar

# %%
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def visualize_random_images(train_folder, val_folder, test_folder, num_images=1, figsize=(4, 4)):
    categories = os.listdir(train_folder)
    
    for category in categories:
        print(f"\nContoh Gambar untuk Kategori {category}:")
        fig, axes = plt.subplots(1, 3, figsize=(figsize[0] * 3, figsize[1]))

        folders = [train_folder, val_folder, test_folder]
        folder_names = ['Train', 'Validation', 'Test']
        
        for ax, folder, folder_name in zip(axes, folders, folder_names):
            category_dir = os.path.join(folder, category)
            images = os.listdir(category_dir)
            if len(images) > 0:
                img_file = random.choice(images)
                img_path = os.path.join(category_dir, img_file)
                img = mpimg.imread(img_path)
                ax.imshow(img)
                ax.axis("off")
                ax.set_title(folder_name)
            else:
                ax.axis("off")
                ax.set_title(f"No Images in {folder_name}")
        
        plt.show()

print('Visualizing Images for Categories:')
visualize_random_images(train_dir, val_dir, test_dir, figsize=(3, 3))
# Out:
# Visualizing Images for Categories:
#
# Contoh Gambar untuk Kategori kitchen:
# Contoh Gambar untuk Kategori living:
# Contoh Gambar untuk Kategori bathroom:
# Contoh Gambar untuk Kategori gaming:
# Contoh Gambar untuk Kategori bedroom:
# Contoh Gambar untuk Kategori dining:
# Contoh Gambar untuk Kategori yard:
# Contoh Gambar untuk Kategori office:
# Contoh Gambar untuk Kategori laundry:
# Contoh Gambar untuk Kategori terrace:

# %%
# Preprocess input images using MobilenetV3 preprocessing layers
preprocess_input = tf.keras.applications.mobilenet_v3.preprocess_input

# Menggunakan ImageDataGenerator untuk pelatihan 
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rescale=1./255,
    rotation_range=10, 
    zoom_range=0.1,
    width_shift_range=0.1, 
    height_shift_range=0.1, 
    shear_range=0.1,
    brightness_range=[0.8, 1.2],
    horizontal_flip=True,  
    vertical_flip=False,
    fill_mode='nearest'
)

traindata = train_datagen.flow_from_directory(
    directory=train_dir, 
    target_size=(224,224), 
    color_mode="rgb", 
    class_mode='categorical',
    shuffle=True)

val_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rescale=1./255
)

valdata = val_datagen.flow_from_directory(
    directory=val_dir, 
    target_size=(224,224), 
    color_mode="rgb", 
    class_mode='categorical',
    shuffle=False)

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rescale=1./255
)

testdata = test_datagen.flow_from_directory(
    directory=test_dir, 
    target_size=(224,224), 
    color_mode="rgb", 
    class_mode='categorical',
    shuffle=False)
# Out:
# Found 7384 images belonging to 10 classes.
# Found 2464 images belonging to 10 classes.
# Found 2463 images belonging to 10 classes.

# %%
print("Informasi Data Training:")
print(f"Jumlah sampel: {traindata.samples}")
print(f"Kelas: {traindata.class_indices}")
print(f"Shape gambar: {traindata.image_shape}")
print(f"Mode warna: {traindata.color_mode}")

print("\nInformasi Data Validasi:")
print(f"Jumlah sampel: {valdata.samples}")
print(f"Kelas: {valdata.class_indices}")
print(f"Shape gambar: {valdata.image_shape}")
print(f"Mode warna: {valdata.color_mode}")

print("\nInformasi Data Test:")
print(f"Jumlah sampel: {testdata.samples}")
print(f"Kelas: {testdata.class_indices}")
print(f"Shape gambar: {testdata.image_shape}")
print(f"Mode warna: {testdata.color_mode}")
# Out:
# Informasi Data Training:
# Jumlah sampel: 7384
# Kelas: {'bathroom': 0, 'bedroom': 1, 'dining': 2, 'gaming': 3, 'kitchen': 4, 'laundry': 5, 'living': 6, 'office': 7, 'terrace': 8, 'yard': 9}
# Shape gambar: (224, 224, 3)
# Mode warna: rgb
#
# Informasi Data Validasi:
# Jumlah sampel: 2464
# Kelas: {'bathroom': 0, 'bedroom': 1, 'dining': 2, 'gaming': 3, 'kitchen': 4, 'laundry': 5, 'living': 6, 'office': 7, 'terrace': 8, 'yard': 9}
# Shape gambar: (224, 224, 3)
# Mode warna: rgb
#
# Informasi Data Test:
# Jumlah sampel: 2463
# Kelas: {'bathroom': 0, 'bedroom': 1, 'dining': 2, 'gaming': 3, 'kitchen': 4, 'laundry': 5, 'living': 6, 'office': 7, 'terrace': 8, 'yard': 9}
# Shape gambar: (224, 224, 3)
# Mode warna: rgb

# %% [markdown]
# ### MODELING

# %%
from tensorflow.keras.applications import MobileNetV3Small

base_model = MobileNetV3Small(input_shape = (224, 224, 3), include_top = False, weights = 'imagenet')

# %%
# Freeze layers except the last 8 layers
for layer in base_model.layers[:-8]:
    layer.trainable = False

# %%
# Check if GPU is available
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    # Set memory growth for GPU
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# Physical devices cannot be modified after being initialized

# %%
from tensorflow import keras
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from keras.regularizers import l2
import tensorflow as tf


model = Sequential()
model.add(Input(shape=(224, 224, 3)))
model.add(base_model)
model.add(Conv2D(512, (3, 3), activation='elu'))
model.add(Conv2D(256, (3, 3), activation='elu'))
model.add(GlobalAveragePooling2D())
model.add(Dense(1024, activation='elu'))
model.add(Dense(512, activation='elu'))
model.add(Dense(len(categories), activation='softmax'))


model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ MobilenetV3small (Functional)   │ (None, 7, 7, 576)      │       939,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 5, 5, 512)      │     2,654,720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 3, 3, 256)      │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │       263,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,566,842 (21.24 MB)
#  Trainable params: 4,739,658 (18.08 MB)
#  Non-trainable params: 827,184 (3.16 MB)

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

device_name = tf.test.gpu_device_name()
modelpath = './output/bestmodel.keras'

# Function to compile and train the model with given parameters
def compile_and_train(model, optimizer, learning_rate, batch_size, modelpath, traindata, valdata):
    with tf.device(device_name):
        if optimizer == 'adam':
            opt = Adam(learning_rate=learning_rate)
        elif optimizer == 'sgd':
            opt = SGD(learning_rate=learning_rate, momentum=0.9)
        elif optimizer == 'rmsprop':
            opt = RMSprop(learning_rate=learning_rate)

        model.compile(
            optimizer=opt,
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )

        early_stopping_acc = EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True, mode='max')
        early_stopping_loss = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, mode='min')
        reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=4, min_lr=0.000005, verbose=1)
        checkpoint = ModelCheckpoint(modelpath, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)

        history = model.fit(
            x=traindata, 
            validation_data=valdata, 
            epochs=200, 
            batch_size=batch_size, 
            callbacks=[early_stopping_acc, early_stopping_loss, reduce_lr, checkpoint]
        )
        return history

# Define the combinations
combinations = [
    {'optimizer': 'adam', 'learning_rate': 0.001, 'batch_size': 32},
    {'optimizer': 'adam', 'learning_rate': 0.0001, 'batch_size': 64},
    {'optimizer': 'sgd', 'learning_rate': 0.01, 'batch_size': 32},
    {'optimizer': 'sgd', 'learning_rate': 0.001, 'batch_size': 64},
    {'optimizer': 'rmsprop', 'learning_rate': 0.001, 'batch_size': 32},
    {'optimizer': 'rmsprop', 'learning_rate': 0.0001, 'batch_size': 64},
]

# List to store evaluation results
results = []

# Loop through combinations and train model
for combo in combinations:
    print(f"Training with optimizer={combo['optimizer']}, learning_rate={combo['learning_rate']}, batch_size={combo['batch_size']}")
    history = compile_and_train(model, combo['optimizer'], combo['learning_rate'], combo['batch_size'], modelpath, traindata, valdata)
    
    # Evaluate model on test data
    test_loss, test_acc = model.evaluate(testdata)
    print(f'Test Loss: {test_loss:.4f}')
    print(f'Test Accuracy: {test_acc * 100:.2f}%')
    
    # Store the results
    results.append({
        'optimizer': combo['optimizer'],
        'learning_rate': combo['learning_rate'],
        'batch_size': combo['batch_size'],
        'test_loss': test_loss,
        'test_acc': test_acc
    })

# Print all results for comparison
for result in results:
    print(f"Optimizer: {result['optimizer']}, Learning Rate: {result['learning_rate']}, Batch Size: {result['batch_size']}")
    print(f"Test Loss: {result['test_loss']:.4f}, Test Accuracy: {result['test_acc'] * 100:.2f}%\n")
# Out:
# Training with optimizer=adam, learning_rate=0.001, batch_size=32
# Epoch 1/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.1679 - loss: 2.8341
# Epoch 1: val_accuracy improved from -inf to 0.10795, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 116s 441ms/step - accuracy: 0.1681 - loss: 2.8305 - val_accuracy: 0.1080 - val_loss: 2.3557 - learning_rate: 0.0010
# Epoch 2/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.2205 - loss: 2.1597
# Epoch 2: val_accuracy improved from 0.10795 to 0.15584, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 97s 407ms/step - accuracy: 0.2205 - loss: 2.1595 - val_accuracy: 0.1558 - val_loss: 2.5074 - learning_rate: 0.0010
# Epoch 3/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.2473 - loss: 2.0982
# Epoch 3: val_accuracy did not improve from 0.15584
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 396ms/step - accuracy: 0.2473 - loss: 2.0982 - val_accuracy: 0.1291 - val_loss: 2.7539 - learning_rate: 0.0010
# Epoch 4/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.2532 - loss: 2.0734
# Epoch 4: val_accuracy did not improve from 0.15584
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 395ms/step - accuracy: 0.2533 - loss: 2.0733 - val_accuracy: 0.1404 - val_loss: 2.6317 - learning_rate: 0.0010
# Epoch 5/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.2631 - loss: 2.0540
# Epoch 5: val_accuracy did not improve from 0.15584
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 400ms/step - accuracy: 0.2632 - loss: 2.0539 - val_accuracy: 0.1404 - val_loss: 2.6251 - learning_rate: 0.0010
# Epoch 6/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.2777 - loss: 2.0491
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 6: val_accuracy did not improve from 0.15584
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 399ms/step - accuracy: 0.2777 - loss: 2.0490 - val_accuracy: 0.1437 - val_loss: 2.7841 - learning_rate: 0.0010
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - accuracy: 0.1930 - loss: 2.1921
# Test Loss: 2.3466
# Test Accuracy: 10.64%
# Training with optimizer=adam, learning_rate=0.0001, batch_size=64
# Epoch 1/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.2593 - loss: 2.0456
# Epoch 1: val_accuracy improved from -inf to 0.12906, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 113s 431ms/step - accuracy: 0.2594 - loss: 2.0455 - val_accuracy: 0.1291 - val_loss: 2.6617 - learning_rate: 1.0000e-04
# Epoch 2/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.2979 - loss: 1.9779
# Epoch 2: val_accuracy did not improve from 0.12906
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 398ms/step - accuracy: 0.2979 - loss: 1.9778 - val_accuracy: 0.1291 - val_loss: 2.7890 - learning_rate: 1.0000e-04
# Epoch 3/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.3029 - loss: 1.9518
# Epoch 3: val_accuracy did not improve from 0.12906
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 395ms/step - accuracy: 0.3029 - loss: 1.9518 - val_accuracy: 0.1291 - val_loss: 3.0509 - learning_rate: 1.0000e-04
# Epoch 4/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.3190 - loss: 1.9217
# Epoch 4: val_accuracy did not improve from 0.12906
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 399ms/step - accuracy: 0.3190 - loss: 1.9216 - val_accuracy: 0.1291 - val_loss: 2.8965 - learning_rate: 1.0000e-04
# Epoch 5/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.3305 - loss: 1.8811
# Epoch 5: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 5: val_accuracy did not improve from 0.12906
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 397ms/step - accuracy: 0.3305 - loss: 1.8813 - val_accuracy: 0.1291 - val_loss: 3.9038 - learning_rate: 1.0000e-04
# Epoch 6/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.3444 - loss: 1.8495
# Epoch 6: val_accuracy improved from 0.12906 to 0.13028, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 397ms/step - accuracy: 0.3445 - loss: 1.8494 - val_accuracy: 0.1303 - val_loss: 3.6646 - learning_rate: 1.0000e-05
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.0842 - loss: 2.4084
# Test Loss: 2.6503
# Test Accuracy: 12.91%
# Training with optimizer=sgd, learning_rate=0.01, batch_size=32
# Epoch 1/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - accuracy: 0.1653 - loss: 2.4155
# Epoch 1: val_accuracy improved from -inf to 0.12703, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 112s 429ms/step - accuracy: 0.1654 - loss: 2.4145 - val_accuracy: 0.1270 - val_loss: 2.7822 - learning_rate: 0.0100
# Epoch 2/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.2264 - loss: 2.1374
# Epoch 2: val_accuracy improved from 0.12703 to 0.18994, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 398ms/step - accuracy: 0.2264 - loss: 2.1373 - val_accuracy: 0.1899 - val_loss: 2.4555 - learning_rate: 0.0100
# Epoch 3/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.2330 - loss: 2.1047
# Epoch 3: val_accuracy did not improve from 0.18994
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 402ms/step - accuracy: 0.2330 - loss: 2.1047 - val_accuracy: 0.1502 - val_loss: 2.5540 - learning_rate: 0.0100
# Epoch 4/200
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.2654 - loss: 2.0440
# Epoch 4: val_accuracy improved from 0.18994 to 0.22240, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 402ms/step - accuracy: 0.2654 - loss: 2.0440 - val_accuracy: 0.2224 - val_loss: 2.1058 - learning_rate: 0.0100
# Epoch 5/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.2656 - loss: 2.0209
# Epoch 5: val_accuracy did not improve from 0.22240
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 140s 394ms/step - accuracy: 0.2656 - loss: 2.0209 - val_accuracy: 0.1388 - val_loss: 2.6230 - learning_rate: 0.0100
# Epoch 6/200
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.2759 - loss: 2.0240
# Epoch 6: val_accuracy did not improve from 0.22240
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 397ms/step - accuracy: 0.2759 - loss: 2.0240 - val_accuracy: 0.1680 - val_loss: 2.3204 - learning_rate: 0.0100
# Epoch 7/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.2778 - loss: 2.0133
# Epoch 7: val_accuracy did not improve from 0.22240
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 397ms/step - accuracy: 0.2779 - loss: 2.0133 - val_accuracy: 0.1968 - val_loss: 2.2767 - learning_rate: 0.0100
# Epoch 8/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.2712 - loss: 2.0042
# Epoch 8: val_accuracy improved from 0.22240 to 0.25041, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 395ms/step - accuracy: 0.2713 - loss: 2.0042 - val_accuracy: 0.2504 - val_loss: 2.0629 - learning_rate: 0.0100
# Epoch 9/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.2939 - loss: 1.9671
# Epoch 9: val_accuracy improved from 0.25041 to 0.27354, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 398ms/step - accuracy: 0.2938 - loss: 1.9672 - val_accuracy: 0.2735 - val_loss: 2.0410 - learning_rate: 0.0100
# Epoch 10/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.2961 - loss: 1.9797
# Epoch 10: val_accuracy did not improve from 0.27354
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 398ms/step - accuracy: 0.2960 - loss: 1.9798 - val_accuracy: 0.2508 - val_loss: 2.0700 - learning_rate: 0.0100
# Epoch 11/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.2823 - loss: 1.9827
# Epoch 11: val_accuracy did not improve from 0.27354
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 400ms/step - accuracy: 0.2824 - loss: 1.9826 - val_accuracy: 0.2670 - val_loss: 2.0303 - learning_rate: 0.0100
# Epoch 12/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.3029 - loss: 1.9569
# Epoch 12: val_accuracy improved from 0.27354 to 0.28247, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 397ms/step - accuracy: 0.3029 - loss: 1.9569 - val_accuracy: 0.2825 - val_loss: 2.0443 - learning_rate: 0.0100
# Epoch 13/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.3044 - loss: 1.9534
# Epoch 13: val_accuracy improved from 0.28247 to 0.28328, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 396ms/step - accuracy: 0.3044 - loss: 1.9534 - val_accuracy: 0.2833 - val_loss: 2.0598 - learning_rate: 0.0100
# Epoch 14/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.3082 - loss: 1.9523
# Epoch 14: val_accuracy did not improve from 0.28328
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 396ms/step - accuracy: 0.3082 - loss: 1.9523 - val_accuracy: 0.2662 - val_loss: 2.0903 - learning_rate: 0.0100
# Epoch 15/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.3043 - loss: 1.9549
# Epoch 15: val_accuracy did not improve from 0.28328
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 394ms/step - accuracy: 0.3043 - loss: 1.9549 - val_accuracy: 0.2581 - val_loss: 2.1779 - learning_rate: 0.0100
# Epoch 16/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.3012 - loss: 1.9439
# Epoch 16: val_accuracy did not improve from 0.28328
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 393ms/step - accuracy: 0.3013 - loss: 1.9438 - val_accuracy: 0.2597 - val_loss: 2.4222 - learning_rate: 0.0100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.2127 - loss: 2.3439
# Test Loss: 1.9961
# Test Accuracy: 27.93%
# Training with optimizer=sgd, learning_rate=0.001, batch_size=64
# Epoch 1/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.3271 - loss: 1.9146
# Epoch 1: val_accuracy improved from -inf to 0.29505, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 112s 431ms/step - accuracy: 0.3271 - loss: 1.9146 - val_accuracy: 0.2950 - val_loss: 1.9844 - learning_rate: 0.0010
# Epoch 2/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.3392 - loss: 1.8709
# Epoch 2: val_accuracy improved from 0.29505 to 0.33036, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 96s 402ms/step - accuracy: 0.3392 - loss: 1.8710 - val_accuracy: 0.3304 - val_loss: 1.9398 - learning_rate: 0.0010
# Epoch 3/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.3388 - loss: 1.8759
# Epoch 3: val_accuracy did not improve from 0.33036
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 395ms/step - accuracy: 0.3387 - loss: 1.8759 - val_accuracy: 0.3129 - val_loss: 1.9742 - learning_rate: 0.0010
# Epoch 4/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.3398 - loss: 1.8728
# Epoch 4: val_accuracy did not improve from 0.33036
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 398ms/step - accuracy: 0.3398 - loss: 1.8729 - val_accuracy: 0.3226 - val_loss: 1.9316 - learning_rate: 0.0010
# Epoch 5/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.3482 - loss: 1.8574
# Epoch 5: val_accuracy improved from 0.33036 to 0.33401, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 142s 398ms/step - accuracy: 0.3481 - loss: 1.8575 - val_accuracy: 0.3340 - val_loss: 1.9198 - learning_rate: 0.0010
# Epoch 6/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.3465 - loss: 1.8558
# Epoch 6: val_accuracy improved from 0.33401 to 0.34010, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 397ms/step - accuracy: 0.3464 - loss: 1.8559 - val_accuracy: 0.3401 - val_loss: 1.9101 - learning_rate: 0.0010
# Epoch 7/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.3467 - loss: 1.8603
# Epoch 7: val_accuracy did not improve from 0.34010
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 398ms/step - accuracy: 0.3467 - loss: 1.8603 - val_accuracy: 0.3267 - val_loss: 1.9355 - learning_rate: 0.0010
# Epoch 8/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.3449 - loss: 1.8509
# Epoch 8: val_accuracy did not improve from 0.34010
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 399ms/step - accuracy: 0.3449 - loss: 1.8510 - val_accuracy: 0.3385 - val_loss: 1.8856 - learning_rate: 0.0010
# Epoch 9/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.3376 - loss: 1.8503
# Epoch 9: val_accuracy improved from 0.34010 to 0.34700, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 396ms/step - accuracy: 0.3376 - loss: 1.8503 - val_accuracy: 0.3470 - val_loss: 1.8667 - learning_rate: 0.0010
# Epoch 10/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.3444 - loss: 1.8531
# Epoch 10: val_accuracy improved from 0.34700 to 0.35268, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 96s 403ms/step - accuracy: 0.3444 - loss: 1.8530 - val_accuracy: 0.3527 - val_loss: 1.8666 - learning_rate: 0.0010
# Epoch 11/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.3397 - loss: 1.8435
# Epoch 11: val_accuracy did not improve from 0.35268
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 395ms/step - accuracy: 0.3397 - loss: 1.8435 - val_accuracy: 0.3433 - val_loss: 1.8982 - learning_rate: 0.0010
# Epoch 12/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.3493 - loss: 1.8526
# Epoch 12: val_accuracy improved from 0.35268 to 0.36120, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 396ms/step - accuracy: 0.3493 - loss: 1.8526 - val_accuracy: 0.3612 - val_loss: 1.8573 - learning_rate: 0.0010
# Epoch 13/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.3663 - loss: 1.8234
# Epoch 13: val_accuracy did not improve from 0.36120
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 394ms/step - accuracy: 0.3661 - loss: 1.8235 - val_accuracy: 0.3584 - val_loss: 1.8401 - learning_rate: 0.0010
# Epoch 14/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.3442 - loss: 1.8460
# Epoch 14: val_accuracy improved from 0.36120 to 0.36404, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 96s 404ms/step - accuracy: 0.3442 - loss: 1.8459 - val_accuracy: 0.3640 - val_loss: 1.8573 - learning_rate: 0.0010
# Epoch 15/200
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.3568 - loss: 1.8402
# Epoch 15: val_accuracy improved from 0.36404 to 0.37094, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 397ms/step - accuracy: 0.3568 - loss: 1.8401 - val_accuracy: 0.3709 - val_loss: 1.8442 - learning_rate: 0.0010
# Epoch 16/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.3621 - loss: 1.8240
# Epoch 16: val_accuracy did not improve from 0.37094
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 399ms/step - accuracy: 0.3621 - loss: 1.8241 - val_accuracy: 0.3669 - val_loss: 1.8309 - learning_rate: 0.0010
# Epoch 17/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.3583 - loss: 1.8230
# Epoch 17: val_accuracy improved from 0.37094 to 0.37622, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 395ms/step - accuracy: 0.3583 - loss: 1.8230 - val_accuracy: 0.3762 - val_loss: 1.8183 - learning_rate: 0.0010
# Epoch 18/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.3649 - loss: 1.8116
# Epoch 18: val_accuracy did not improve from 0.37622
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 401ms/step - accuracy: 0.3648 - loss: 1.8117 - val_accuracy: 0.3750 - val_loss: 1.8223 - learning_rate: 0.0010
# Epoch 19/200
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.3597 - loss: 1.8165
# Epoch 19: val_accuracy did not improve from 0.37622
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 142s 400ms/step - accuracy: 0.3597 - loss: 1.8165 - val_accuracy: 0.3612 - val_loss: 1.8632 - learning_rate: 0.0010
# Epoch 20/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.3653 - loss: 1.8317
# Epoch 20: val_accuracy did not improve from 0.37622
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 398ms/step - accuracy: 0.3652 - loss: 1.8317 - val_accuracy: 0.3661 - val_loss: 1.8216 - learning_rate: 0.0010
# Epoch 21/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.3595 - loss: 1.8333
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 21: val_accuracy did not improve from 0.37622
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 396ms/step - accuracy: 0.3595 - loss: 1.8332 - val_accuracy: 0.3701 - val_loss: 1.8191 - learning_rate: 0.0010
# Epoch 22/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.3616 - loss: 1.8111
# Epoch 22: val_accuracy improved from 0.37622 to 0.38758, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 401ms/step - accuracy: 0.3617 - loss: 1.8110 - val_accuracy: 0.3876 - val_loss: 1.7803 - learning_rate: 1.0000e-04
# Epoch 23/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.3722 - loss: 1.8062
# Epoch 23: val_accuracy improved from 0.38758 to 0.39002, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 396ms/step - accuracy: 0.3723 - loss: 1.8060 - val_accuracy: 0.3900 - val_loss: 1.7831 - learning_rate: 1.0000e-04
# Epoch 24/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.3740 - loss: 1.7851
# Epoch 24: val_accuracy did not improve from 0.39002
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 399ms/step - accuracy: 0.3741 - loss: 1.7850 - val_accuracy: 0.3892 - val_loss: 1.7806 - learning_rate: 1.0000e-04
# Epoch 25/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.3688 - loss: 1.7902
# Epoch 25: val_accuracy improved from 0.39002 to 0.39123, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 143s 403ms/step - accuracy: 0.3688 - loss: 1.7901 - val_accuracy: 0.3912 - val_loss: 1.7798 - learning_rate: 1.0000e-04
# Epoch 26/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.3739 - loss: 1.7645
# Epoch 26: val_accuracy did not improve from 0.39123
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 396ms/step - accuracy: 0.3739 - loss: 1.7646 - val_accuracy: 0.3900 - val_loss: 1.7742 - learning_rate: 1.0000e-04
# Epoch 27/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.3675 - loss: 1.7884
# Epoch 27: val_accuracy did not improve from 0.39123
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 397ms/step - accuracy: 0.3675 - loss: 1.7884 - val_accuracy: 0.3912 - val_loss: 1.7754 - learning_rate: 1.0000e-04
# Epoch 28/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.3786 - loss: 1.7755
# Epoch 28: val_accuracy improved from 0.39123 to 0.39164, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 394ms/step - accuracy: 0.3786 - loss: 1.7756 - val_accuracy: 0.3916 - val_loss: 1.7765 - learning_rate: 1.0000e-04
# Epoch 29/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.3744 - loss: 1.7855
# Epoch 29: val_accuracy improved from 0.39164 to 0.39326, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 401ms/step - accuracy: 0.3744 - loss: 1.7854 - val_accuracy: 0.3933 - val_loss: 1.7750 - learning_rate: 1.0000e-04
# Epoch 30/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.3681 - loss: 1.7871
# Epoch 30: val_accuracy did not improve from 0.39326
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 393ms/step - accuracy: 0.3681 - loss: 1.7870 - val_accuracy: 0.3933 - val_loss: 1.7720 - learning_rate: 1.0000e-04
# Epoch 31/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.3874 - loss: 1.7691
# Epoch 31: val_accuracy improved from 0.39326 to 0.39610, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 397ms/step - accuracy: 0.3873 - loss: 1.7692 - val_accuracy: 0.3961 - val_loss: 1.7708 - learning_rate: 1.0000e-04
# Epoch 32/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.3634 - loss: 1.7815
# Epoch 32: val_accuracy did not improve from 0.39610
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 394ms/step - accuracy: 0.3635 - loss: 1.7815 - val_accuracy: 0.3920 - val_loss: 1.7772 - learning_rate: 1.0000e-04
# Epoch 33/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.3878 - loss: 1.7699
# Epoch 33: val_accuracy did not improve from 0.39610
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 394ms/step - accuracy: 0.3877 - loss: 1.7698 - val_accuracy: 0.3945 - val_loss: 1.7677 - learning_rate: 1.0000e-04
# Epoch 34/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.3759 - loss: 1.7657
# Epoch 34: val_accuracy did not improve from 0.39610
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 399ms/step - accuracy: 0.3759 - loss: 1.7657 - val_accuracy: 0.3953 - val_loss: 1.7707 - learning_rate: 1.0000e-04
# Epoch 35/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.3784 - loss: 1.7769
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 35: val_accuracy did not improve from 0.39610
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 400ms/step - accuracy: 0.3784 - loss: 1.7769 - val_accuracy: 0.3945 - val_loss: 1.7736 - learning_rate: 1.0000e-04
# Epoch 36/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.3946 - loss: 1.7536
# Epoch 36: val_accuracy did not improve from 0.39610
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 397ms/step - accuracy: 0.3946 - loss: 1.7536 - val_accuracy: 0.3953 - val_loss: 1.7693 - learning_rate: 1.0000e-05
# Epoch 37/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.3769 - loss: 1.7772
# Epoch 37: val_accuracy improved from 0.39610 to 0.39692, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 400ms/step - accuracy: 0.3770 - loss: 1.7770 - val_accuracy: 0.3969 - val_loss: 1.7665 - learning_rate: 1.0000e-05
# Epoch 38/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.3793 - loss: 1.7649
# Epoch 38: val_accuracy improved from 0.39692 to 0.39976, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 395ms/step - accuracy: 0.3794 - loss: 1.7648 - val_accuracy: 0.3998 - val_loss: 1.7637 - learning_rate: 1.0000e-05
# Epoch 39/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.3915 - loss: 1.7602
# Epoch 39: val_accuracy did not improve from 0.39976
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 392ms/step - accuracy: 0.3915 - loss: 1.7601 - val_accuracy: 0.3981 - val_loss: 1.7626 - learning_rate: 1.0000e-05
# Epoch 40/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.3816 - loss: 1.7748
# Epoch 40: val_accuracy improved from 0.39976 to 0.40097, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 96s 403ms/step - accuracy: 0.3817 - loss: 1.7747 - val_accuracy: 0.4010 - val_loss: 1.7597 - learning_rate: 1.0000e-05
# Epoch 41/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.3793 - loss: 1.7612
# Epoch 41: val_accuracy did not improve from 0.40097
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 398ms/step - accuracy: 0.3793 - loss: 1.7612 - val_accuracy: 0.4010 - val_loss: 1.7588 - learning_rate: 1.0000e-05
# Epoch 42/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.3823 - loss: 1.7666
# Epoch 42: val_accuracy did not improve from 0.40097
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 394ms/step - accuracy: 0.3823 - loss: 1.7667 - val_accuracy: 0.3985 - val_loss: 1.7587 - learning_rate: 1.0000e-05
# Epoch 43/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.3759 - loss: 1.7722
# Epoch 43: val_accuracy did not improve from 0.40097
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 393ms/step - accuracy: 0.3759 - loss: 1.7721 - val_accuracy: 0.4010 - val_loss: 1.7557 - learning_rate: 1.0000e-05
# Epoch 44/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.3891 - loss: 1.7591
# Epoch 44: ReduceLROnPlateau reducing learning rate to 5e-06.
#
# Epoch 44: val_accuracy did not improve from 0.40097
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 394ms/step - accuracy: 0.3891 - loss: 1.7592 - val_accuracy: 0.3998 - val_loss: 1.7547 - learning_rate: 1.0000e-05
# Epoch 45/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.3731 - loss: 1.7652
# Epoch 45: val_accuracy did not improve from 0.40097
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 393ms/step - accuracy: 0.3731 - loss: 1.7652 - val_accuracy: 0.4006 - val_loss: 1.7530 - learning_rate: 5.0000e-06
# Epoch 46/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.3892 - loss: 1.7580
# Epoch 46: val_accuracy improved from 0.40097 to 0.40300, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 395ms/step - accuracy: 0.3891 - loss: 1.7581 - val_accuracy: 0.4030 - val_loss: 1.7536 - learning_rate: 5.0000e-06
# Epoch 47/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.3841 - loss: 1.7640
# Epoch 47: val_accuracy improved from 0.40300 to 0.40503, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 401ms/step - accuracy: 0.3841 - loss: 1.7640 - val_accuracy: 0.4050 - val_loss: 1.7532 - learning_rate: 5.0000e-06
# Epoch 48/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.3899 - loss: 1.7447
# Epoch 48: val_accuracy did not improve from 0.40503
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 393ms/step - accuracy: 0.3898 - loss: 1.7448 - val_accuracy: 0.4042 - val_loss: 1.7525 - learning_rate: 5.0000e-06
# Epoch 49/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.3835 - loss: 1.7703
# Epoch 49: val_accuracy did not improve from 0.40503
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 392ms/step - accuracy: 0.3835 - loss: 1.7702 - val_accuracy: 0.4046 - val_loss: 1.7513 - learning_rate: 5.0000e-06
# Epoch 50/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.4035 - loss: 1.7425
# Epoch 50: val_accuracy did not improve from 0.40503
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 393ms/step - accuracy: 0.4034 - loss: 1.7426 - val_accuracy: 0.4042 - val_loss: 1.7503 - learning_rate: 5.0000e-06
# Epoch 51/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.3852 - loss: 1.7649
# Epoch 51: val_accuracy did not improve from 0.40503
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 142s 392ms/step - accuracy: 0.3853 - loss: 1.7649 - val_accuracy: 0.4038 - val_loss: 1.7521 - learning_rate: 5.0000e-06
# Epoch 52/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.3927 - loss: 1.7496
# Epoch 52: val_accuracy did not improve from 0.40503
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 391ms/step - accuracy: 0.3926 - loss: 1.7497 - val_accuracy: 0.4010 - val_loss: 1.7531 - learning_rate: 5.0000e-06
# Epoch 53/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.3882 - loss: 1.7454
# Epoch 53: val_accuracy did not improve from 0.40503
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 392ms/step - accuracy: 0.3882 - loss: 1.7455 - val_accuracy: 0.4046 - val_loss: 1.7511 - learning_rate: 5.0000e-06
# Epoch 54/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.3812 - loss: 1.7717
# Epoch 54: val_accuracy did not improve from 0.40503
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 393ms/step - accuracy: 0.3813 - loss: 1.7716 - val_accuracy: 0.4034 - val_loss: 1.7520 - learning_rate: 5.0000e-06
# Epoch 55/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.3722 - loss: 1.7785
# Epoch 55: val_accuracy did not improve from 0.40503
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 392ms/step - accuracy: 0.3723 - loss: 1.7784 - val_accuracy: 0.4030 - val_loss: 1.7523 - learning_rate: 5.0000e-06
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.3186 - loss: 1.9043
# Test Loss: 1.7240
# Test Accuracy: 39.22%
# Training with optimizer=rmsprop, learning_rate=0.001, batch_size=32
# Epoch 1/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.1360 - loss: 3.3081
# Epoch 1: val_accuracy improved from -inf to 0.13149, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 110s 424ms/step - accuracy: 0.1361 - loss: 3.3016 - val_accuracy: 0.1315 - val_loss: 2.3132 - learning_rate: 0.0010
# Epoch 2/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.1971 - loss: 2.2163
# Epoch 2: val_accuracy improved from 0.13149 to 0.21834, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 397ms/step - accuracy: 0.1972 - loss: 2.2161 - val_accuracy: 0.2183 - val_loss: 2.1332 - learning_rate: 0.0010
# Epoch 3/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.2152 - loss: 2.1523
# Epoch 3: val_accuracy improved from 0.21834 to 0.28896, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 395ms/step - accuracy: 0.2153 - loss: 2.1522 - val_accuracy: 0.2890 - val_loss: 2.0127 - learning_rate: 0.0010
# Epoch 4/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.2408 - loss: 2.1016
# Epoch 4: val_accuracy did not improve from 0.28896
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 397ms/step - accuracy: 0.2409 - loss: 2.1017 - val_accuracy: 0.1944 - val_loss: 2.4507 - learning_rate: 0.0010
# Epoch 5/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.2533 - loss: 2.1131
# Epoch 5: val_accuracy did not improve from 0.28896
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 399ms/step - accuracy: 0.2534 - loss: 2.1130 - val_accuracy: 0.1972 - val_loss: 2.1916 - learning_rate: 0.0010
# Epoch 6/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.2613 - loss: 2.0561
# Epoch 6: val_accuracy did not improve from 0.28896
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 398ms/step - accuracy: 0.2614 - loss: 2.0562 - val_accuracy: 0.2131 - val_loss: 2.2937 - learning_rate: 0.0010
# Epoch 7/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.2675 - loss: 2.0558
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 7: val_accuracy did not improve from 0.28896
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 395ms/step - accuracy: 0.2675 - loss: 2.0558 - val_accuracy: 0.1603 - val_loss: 2.4082 - learning_rate: 0.0010
# Epoch 8/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.3317 - loss: 1.8815
# Epoch 8: val_accuracy did not improve from 0.28896
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 399ms/step - accuracy: 0.3318 - loss: 1.8813 - val_accuracy: 0.2009 - val_loss: 2.3126 - learning_rate: 1.0000e-04
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.2374 - loss: 2.2276
# Test Loss: 1.9851
# Test Accuracy: 28.87%
# Training with optimizer=rmsprop, learning_rate=0.0001, batch_size=64
# Epoch 1/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.2988 - loss: 1.9613
# Epoch 1: val_accuracy improved from -inf to 0.24229, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 110s 426ms/step - accuracy: 0.2990 - loss: 1.9610 - val_accuracy: 0.2423 - val_loss: 2.1034 - learning_rate: 1.0000e-04
# Epoch 2/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.3315 - loss: 1.8881
# Epoch 2: val_accuracy did not improve from 0.24229
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 392ms/step - accuracy: 0.3314 - loss: 1.8881 - val_accuracy: 0.2366 - val_loss: 2.1572 - learning_rate: 1.0000e-04
# Epoch 3/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.3296 - loss: 1.8835
# Epoch 3: val_accuracy did not improve from 0.24229
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 394ms/step - accuracy: 0.3297 - loss: 1.8835 - val_accuracy: 0.2378 - val_loss: 2.1724 - learning_rate: 1.0000e-04
# Epoch 4/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.3272 - loss: 1.8768
# Epoch 4: val_accuracy did not improve from 0.24229
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 397ms/step - accuracy: 0.3272 - loss: 1.8766 - val_accuracy: 0.2394 - val_loss: 2.1139 - learning_rate: 1.0000e-04
# Epoch 5/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.3391 - loss: 1.8425
# Epoch 5: val_accuracy improved from 0.24229 to 0.26177, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 402ms/step - accuracy: 0.3391 - loss: 1.8426 - val_accuracy: 0.2618 - val_loss: 2.0974 - learning_rate: 1.0000e-04
# Epoch 6/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.3442 - loss: 1.8337
# Epoch 6: val_accuracy improved from 0.26177 to 0.27516, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 400ms/step - accuracy: 0.3442 - loss: 1.8337 - val_accuracy: 0.2752 - val_loss: 2.0605 - learning_rate: 1.0000e-04
# Epoch 7/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.3513 - loss: 1.8076
# Epoch 7: val_accuracy improved from 0.27516 to 0.28409, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 397ms/step - accuracy: 0.3512 - loss: 1.8077 - val_accuracy: 0.2841 - val_loss: 2.0190 - learning_rate: 1.0000e-04
# Epoch 8/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.3629 - loss: 1.8180
# Epoch 8: val_accuracy did not improve from 0.28409
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 392ms/step - accuracy: 0.3629 - loss: 1.8180 - val_accuracy: 0.2695 - val_loss: 2.0664 - learning_rate: 1.0000e-04
# Epoch 9/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.3685 - loss: 1.8006
# Epoch 9: val_accuracy did not improve from 0.28409
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 396ms/step - accuracy: 0.3685 - loss: 1.8007 - val_accuracy: 0.2804 - val_loss: 2.0772 - learning_rate: 1.0000e-04
# Epoch 10/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.3621 - loss: 1.8092
# Epoch 10: val_accuracy improved from 0.28409 to 0.30560, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 393ms/step - accuracy: 0.3621 - loss: 1.8091 - val_accuracy: 0.3056 - val_loss: 1.9344 - learning_rate: 1.0000e-04
# Epoch 11/200
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.3735 - loss: 1.8042
# Epoch 11: val_accuracy did not improve from 0.30560
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 402ms/step - accuracy: 0.3735 - loss: 1.8041 - val_accuracy: 0.3044 - val_loss: 2.0542 - learning_rate: 1.0000e-04
# Epoch 12/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.3634 - loss: 1.7865
# Epoch 12: val_accuracy improved from 0.30560 to 0.33726, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 97s 407ms/step - accuracy: 0.3634 - loss: 1.7865 - val_accuracy: 0.3373 - val_loss: 1.9276 - learning_rate: 1.0000e-04
# Epoch 13/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.3754 - loss: 1.7586
# Epoch 13: val_accuracy did not improve from 0.33726
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 394ms/step - accuracy: 0.3753 - loss: 1.7587 - val_accuracy: 0.3316 - val_loss: 1.8686 - learning_rate: 1.0000e-04
# Epoch 14/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.3738 - loss: 1.7754
# Epoch 14: val_accuracy did not improve from 0.33726
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 395ms/step - accuracy: 0.3739 - loss: 1.7754 - val_accuracy: 0.3336 - val_loss: 1.8851 - learning_rate: 1.0000e-04
# Epoch 15/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.3759 - loss: 1.7656
# Epoch 15: val_accuracy improved from 0.33726 to 0.35552, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 399ms/step - accuracy: 0.3759 - loss: 1.7656 - val_accuracy: 0.3555 - val_loss: 1.8114 - learning_rate: 1.0000e-04
# Epoch 16/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.3759 - loss: 1.7634
# Epoch 16: val_accuracy improved from 0.35552 to 0.36972, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 399ms/step - accuracy: 0.3759 - loss: 1.7633 - val_accuracy: 0.3697 - val_loss: 1.8145 - learning_rate: 1.0000e-04
# Epoch 17/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.3956 - loss: 1.7317
# Epoch 17: val_accuracy did not improve from 0.36972
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 393ms/step - accuracy: 0.3955 - loss: 1.7320 - val_accuracy: 0.3409 - val_loss: 1.8862 - learning_rate: 1.0000e-04
# Epoch 18/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.3936 - loss: 1.7320
# Epoch 18: val_accuracy did not improve from 0.36972
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 397ms/step - accuracy: 0.3936 - loss: 1.7321 - val_accuracy: 0.3620 - val_loss: 1.8020 - learning_rate: 1.0000e-04
# Epoch 19/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.3952 - loss: 1.7120
# Epoch 19: val_accuracy improved from 0.36972 to 0.38271, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 402ms/step - accuracy: 0.3951 - loss: 1.7122 - val_accuracy: 0.3827 - val_loss: 1.7751 - learning_rate: 1.0000e-04
# Epoch 20/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.3938 - loss: 1.7205
# Epoch 20: val_accuracy did not improve from 0.38271
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 391ms/step - accuracy: 0.3938 - loss: 1.7205 - val_accuracy: 0.3409 - val_loss: 1.8950 - learning_rate: 1.0000e-04
# Epoch 21/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.3886 - loss: 1.7248
# Epoch 21: val_accuracy did not improve from 0.38271
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 391ms/step - accuracy: 0.3886 - loss: 1.7248 - val_accuracy: 0.3787 - val_loss: 1.7567 - learning_rate: 1.0000e-04
# Epoch 22/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.3954 - loss: 1.7051
# Epoch 22: val_accuracy did not improve from 0.38271
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 392ms/step - accuracy: 0.3954 - loss: 1.7051 - val_accuracy: 0.3498 - val_loss: 1.8470 - learning_rate: 1.0000e-04
# Epoch 23/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.4027 - loss: 1.7164
# Epoch 23: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 23: val_accuracy did not improve from 0.38271
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 391ms/step - accuracy: 0.4027 - loss: 1.7163 - val_accuracy: 0.3718 - val_loss: 1.8144 - learning_rate: 1.0000e-04
# Epoch 24/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.4330 - loss: 1.6310
# Epoch 24: val_accuracy improved from 0.38271 to 0.39529, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 394ms/step - accuracy: 0.4330 - loss: 1.6312 - val_accuracy: 0.3953 - val_loss: 1.7431 - learning_rate: 1.0000e-05
# Epoch 25/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.4381 - loss: 1.6443
# Epoch 25: val_accuracy improved from 0.39529 to 0.39773, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 397ms/step - accuracy: 0.4380 - loss: 1.6443 - val_accuracy: 0.3977 - val_loss: 1.7379 - learning_rate: 1.0000e-05
# Epoch 26/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.4260 - loss: 1.6443
# Epoch 26: val_accuracy improved from 0.39773 to 0.40057, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 96s 404ms/step - accuracy: 0.4260 - loss: 1.6443 - val_accuracy: 0.4006 - val_loss: 1.7300 - learning_rate: 1.0000e-05
# Epoch 27/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.4383 - loss: 1.6153
# Epoch 27: val_accuracy improved from 0.40057 to 0.40138, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 396ms/step - accuracy: 0.4382 - loss: 1.6154 - val_accuracy: 0.4014 - val_loss: 1.7183 - learning_rate: 1.0000e-05
# Epoch 28/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.4370 - loss: 1.6201
# Epoch 28: val_accuracy improved from 0.40138 to 0.41031, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 396ms/step - accuracy: 0.4369 - loss: 1.6202 - val_accuracy: 0.4103 - val_loss: 1.6970 - learning_rate: 1.0000e-05
# Epoch 29/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.4206 - loss: 1.6432
# Epoch 29: val_accuracy did not improve from 0.41031
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 401ms/step - accuracy: 0.4207 - loss: 1.6432 - val_accuracy: 0.4091 - val_loss: 1.6985 - learning_rate: 1.0000e-05
# Epoch 30/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.4288 - loss: 1.6505
# Epoch 30: val_accuracy improved from 0.41031 to 0.41883, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 400ms/step - accuracy: 0.4288 - loss: 1.6504 - val_accuracy: 0.4188 - val_loss: 1.6854 - learning_rate: 1.0000e-05
# Epoch 31/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.4457 - loss: 1.6011
# Epoch 31: val_accuracy did not improve from 0.41883
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 394ms/step - accuracy: 0.4456 - loss: 1.6013 - val_accuracy: 0.4180 - val_loss: 1.6815 - learning_rate: 1.0000e-05
# Epoch 32/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.4378 - loss: 1.6460
# Epoch 32: val_accuracy improved from 0.41883 to 0.42289, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 394ms/step - accuracy: 0.4377 - loss: 1.6459 - val_accuracy: 0.4229 - val_loss: 1.6870 - learning_rate: 1.0000e-05
# Epoch 33/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.4319 - loss: 1.6236
# Epoch 33: val_accuracy improved from 0.42289 to 0.42330, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 402ms/step - accuracy: 0.4319 - loss: 1.6236 - val_accuracy: 0.4233 - val_loss: 1.6674 - learning_rate: 1.0000e-05
# Epoch 34/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.4298 - loss: 1.6313
# Epoch 34: val_accuracy improved from 0.42330 to 0.43506, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 394ms/step - accuracy: 0.4298 - loss: 1.6313 - val_accuracy: 0.4351 - val_loss: 1.6495 - learning_rate: 1.0000e-05
# Epoch 35/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.4288 - loss: 1.6189
# Epoch 35: val_accuracy did not improve from 0.43506
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 391ms/step - accuracy: 0.4288 - loss: 1.6190 - val_accuracy: 0.4278 - val_loss: 1.6654 - learning_rate: 1.0000e-05
# Epoch 36/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.4333 - loss: 1.6136
# Epoch 36: val_accuracy did not improve from 0.43506
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 143s 394ms/step - accuracy: 0.4332 - loss: 1.6138 - val_accuracy: 0.4274 - val_loss: 1.6541 - learning_rate: 1.0000e-05
# Epoch 37/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.4293 - loss: 1.6324
# Epoch 37: val_accuracy did not improve from 0.43506
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 392ms/step - accuracy: 0.4293 - loss: 1.6323 - val_accuracy: 0.4326 - val_loss: 1.6447 - learning_rate: 1.0000e-05
# Epoch 38/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.4377 - loss: 1.6207
# Epoch 38: ReduceLROnPlateau reducing learning rate to 5e-06.
#
# Epoch 38: val_accuracy did not improve from 0.43506
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 401ms/step - accuracy: 0.4377 - loss: 1.6207 - val_accuracy: 0.4282 - val_loss: 1.6506 - learning_rate: 1.0000e-05
# Epoch 39/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.4324 - loss: 1.6359
# Epoch 39: val_accuracy did not improve from 0.43506
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 398ms/step - accuracy: 0.4325 - loss: 1.6359 - val_accuracy: 0.4326 - val_loss: 1.6463 - learning_rate: 5.0000e-06
# Epoch 40/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.4275 - loss: 1.6245
# Epoch 40: val_accuracy did not improve from 0.43506
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 397ms/step - accuracy: 0.4276 - loss: 1.6246 - val_accuracy: 0.4334 - val_loss: 1.6428 - learning_rate: 5.0000e-06
# Epoch 41/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.4633 - loss: 1.5754
# Epoch 41: val_accuracy did not improve from 0.43506
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 392ms/step - accuracy: 0.4631 - loss: 1.5757 - val_accuracy: 0.4310 - val_loss: 1.6552 - learning_rate: 5.0000e-06
# Epoch 42/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.4355 - loss: 1.6122
# Epoch 42: val_accuracy did not improve from 0.43506
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 391ms/step - accuracy: 0.4355 - loss: 1.6122 - val_accuracy: 0.4338 - val_loss: 1.6421 - learning_rate: 5.0000e-06
# Epoch 43/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.4420 - loss: 1.6047
# Epoch 43: val_accuracy improved from 0.43506 to 0.43628, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 400ms/step - accuracy: 0.4420 - loss: 1.6047 - val_accuracy: 0.4363 - val_loss: 1.6395 - learning_rate: 5.0000e-06
# Epoch 44/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.4345 - loss: 1.6140
# Epoch 44: val_accuracy did not improve from 0.43628
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 393ms/step - accuracy: 0.4344 - loss: 1.6140 - val_accuracy: 0.4343 - val_loss: 1.6373 - learning_rate: 5.0000e-06
# Epoch 45/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.4396 - loss: 1.6209
# Epoch 45: val_accuracy did not improve from 0.43628
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 391ms/step - accuracy: 0.4396 - loss: 1.6209 - val_accuracy: 0.4326 - val_loss: 1.6392 - learning_rate: 5.0000e-06
# Epoch 46/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.4455 - loss: 1.6011
# Epoch 46: val_accuracy improved from 0.43628 to 0.43912, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 397ms/step - accuracy: 0.4454 - loss: 1.6013 - val_accuracy: 0.4391 - val_loss: 1.6354 - learning_rate: 5.0000e-06
# Epoch 47/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.4413 - loss: 1.5963
# Epoch 47: val_accuracy did not improve from 0.43912
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 392ms/step - accuracy: 0.4412 - loss: 1.5964 - val_accuracy: 0.4379 - val_loss: 1.6355 - learning_rate: 5.0000e-06
# Epoch 48/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.4288 - loss: 1.6235
# Epoch 48: val_accuracy did not improve from 0.43912
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 394ms/step - accuracy: 0.4288 - loss: 1.6234 - val_accuracy: 0.4387 - val_loss: 1.6327 - learning_rate: 5.0000e-06
# Epoch 49/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.4338 - loss: 1.6152
# Epoch 49: val_accuracy did not improve from 0.43912
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 399ms/step - accuracy: 0.4338 - loss: 1.6153 - val_accuracy: 0.4379 - val_loss: 1.6336 - learning_rate: 5.0000e-06
# Epoch 50/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.4331 - loss: 1.6114
# Epoch 50: val_accuracy did not improve from 0.43912
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 397ms/step - accuracy: 0.4332 - loss: 1.6114 - val_accuracy: 0.4351 - val_loss: 1.6331 - learning_rate: 5.0000e-06
# Epoch 51/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.4405 - loss: 1.6121
# Epoch 51: val_accuracy did not improve from 0.43912
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 397ms/step - accuracy: 0.4405 - loss: 1.6121 - val_accuracy: 0.4359 - val_loss: 1.6431 - learning_rate: 5.0000e-06
# Epoch 52/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.4402 - loss: 1.6007
# Epoch 52: val_accuracy did not improve from 0.43912
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 397ms/step - accuracy: 0.4402 - loss: 1.6008 - val_accuracy: 0.4347 - val_loss: 1.6404 - learning_rate: 5.0000e-06
# Epoch 53/200
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.4386 - loss: 1.6015
# Epoch 53: val_accuracy did not improve from 0.43912
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 399ms/step - accuracy: 0.4386 - loss: 1.6015 - val_accuracy: 0.4343 - val_loss: 1.6393 - learning_rate: 5.0000e-06
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.3631 - loss: 1.8014
# Test Loss: 1.6325
# Test Accuracy: 42.47%
# Optimizer: adam, Learning Rate: 0.001, Batch Size: 32
# Test Loss: 2.3466, Test Accuracy: 10.64%
#
# Optimizer: adam, Learning Rate: 0.0001, Batch Size: 64
# Test Loss: 2.6503, Test Accuracy: 12.91%
#
# Optimizer: sgd, Learning Rate: 0.01, Batch Size: 32
# Test Loss: 1.9961, Test Accuracy: 27.93%
#
# Optimizer: sgd, Learning Rate: 0.001, Batch Size: 64
# Test Loss: 1.7240, Test Accuracy: 39.22%
#
# Optimizer: rmsprop, Learning Rate: 0.001, Batch Size: 32
# Test Loss: 1.9851, Test Accuracy: 28.87%
#
# Optimizer: rmsprop, Learning Rate: 0.0001, Batch Size: 64
# Test Loss: 1.6325, Test Accuracy: 42.47%

# %%
# Evaluasi model pada data test
test_loss, test_acc = model.evaluate(testdata)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_acc * 100:.2f}%')
# Out:
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.3631 - loss: 1.8014
# Test Loss: 1.6325
# Test Accuracy: 42.47%

# %%
# Visualize the model

plt.plot(history.history['accuracy'], marker='o')
plt.plot(history.history['val_accuracy'], marker='o')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'], marker='o')
plt.plot(history.history['val_loss'], marker='o')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

# Prediksi label kelas menggunakan model terhadap data uji
predictions = model.predict(testdata)
predicted_classes = np.argmax(predictions, axis=1)

# Ambil label sebenarnya dari data uji
true_classes = testdata.labels

# Dapatkan nama kelas
class_labels = list(testdata.class_indices.keys())

# Buat classification matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Print classification matrix
print("Classification Matrix:")
print(cm)

# Print classification report
print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))
# Out:
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 10s 85ms/step
# Classification Matrix:
# [[ 23  26   3   5  11  49   6  10   5  10]
#  [ 11  72   8  14  18  43  20  10  10  11]
#  [  4  11  93   6  24  21  32   7  15  21]
#  [  2  13  11 174  12  20  26  17  17  10]
#  [  4  16  14  14  83  61  18   8  16   7]
#  [ 12  24   8  13  52 183   8   6   8   4]
#  [  3  18  29  13  10  12 103   7  29   9]
#  [  4  16  20  35  27  52  24  35  30   5]
#  [  4  14   9   7  10  18  11   4  73  92]
#  [  3   5   4   6   5   8   4   5  33 207]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     bathroom       0.33      0.16      0.21       148
#      bedroom       0.33      0.33      0.33       217
#       dining       0.47      0.40      0.43       234
#       gaming       0.61      0.58      0.59       302
#      kitchen       0.33      0.34      0.34       241
#      laundry       0.39      0.58      0.47       318
#       living       0.41      0.44      0.42       233
#       office       0.32      0.14      0.20       248
#      terrace       0.31      0.30      0.31       242
#         yard       0.55      0.74      0.63       280
#
#     accuracy                           0.42      2463
#    macro avg       0.40      0.40      0.39      2463
# weighted avg       0.41      0.42      0.41      2463

# %% [markdown]
# Accuracy adalah rasio dari jumlah prediksi yang benar (true predictions) dibagi dengan jumlah total instance dalam dataset.

# %% [markdown]
# Precision mengukur seberapa akurat model dalam memprediksi kelas positif. Ini dihitung sebagai rasio dari true positive (TP) dibagi oleh jumlah true positive dan false positive (FP).

# %% [markdown]
#  Recall mengukur seberapa baik model dalam menemukan semua instance yang benar dari kelas yang diinginkan. Ini dihitung sebagai rasio dari true positive (TP) dibagi oleh jumlah true positive dan false negative (FN).

# %% [markdown]
# F1-score adalah rata-rata harmonik dari precision dan recall. Ini memberikan keseimbangan antara precision dan recall.
