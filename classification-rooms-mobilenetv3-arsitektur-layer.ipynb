# %% [markdown]
# <a href="https://www.kaggle.com/code/calvinadi/classification-rooms-mobilenetv3-arsitektur-layer?scriptVersionId=185517005" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import random

import glob as gb
import cv2
import matplotlib.pylab as plt
plt.style.use('ggplot')

# %% [markdown]
# ### Dataset source: https://www.kaggle.com/datasets/annielu21/house-rooms

# %%
import warnings

warnings.filterwarnings("ignore", message="All log messages before absl::InitializeLog() is called are written to STDERR")
warnings.filterwarnings("ignore", message="Fallback to op-by-op mode because memset node breaks graph update")

# %%
from sklearn.model_selection import train_test_split
import os
import shutil
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
# Out:
# 2024-06-26 07:25:10.249542: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-26 07:25:10.249602: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-26 07:25:10.251253: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    tf.random.set_seed(random_seed)
    os.environ['PYTHONHASHSEED'] = str(random_seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'

# %%
set_random_seed(42)

# %%
# Path gambar
img_path = '/kaggle/input/processed-room-image/clahe_processed_images'

input_dir = 'images'
output_dir = 'output'

# Membuat folder output jika belum ada
os.makedirs(output_dir, exist_ok=True)

# %%
# Membuat Folder Kategori
categories = ['bathroom', 'bedroom', 'dining', 'gaming', 
              'kitchen','laundry','living', 'office',
             'terrace', 'yard']

for category in categories:
    category_dir = os.path.join(output_dir, category)
    os.makedirs(category_dir, exist_ok=True)

# %%
# Memindahkan file ke folder yang dipilih
for root, dirs, files in os.walk(img_path):
    for file in files:
        category = os.path.basename(root)
        if category in categories:
            source_file = os.path.join(root, file)
            destination_dir = os.path.join(output_dir, category)
            shutil.copy(source_file, destination_dir)

# Menampilkan jumlah file dalam setiap kategori
for category in categories:
    category_dir = os.path.join(output_dir, category)
    num_files = len(os.listdir(category_dir))
    print(f"Total {category} files: {num_files}")
# Out:
# Total bathroom files: 740
# Total bedroom files: 1083
# Total dining files: 1178
# Total gaming files: 1511
# Total kitchen files: 1208
# Total laundry files: 1589
# Total living files: 1164
# Total office files: 1241
# Total terrace files: 1210
# Total yard files: 1398

# %%
# Buat folder train, validation, dan test
train_dir = os.path.join(output_dir, "train")
val_dir = os.path.join(output_dir, "validation")
test_dir = os.path.join(output_dir, "test")

if os.path.exists(train_dir):
    shutil.rmtree(train_dir)
if os.path.exists(val_dir):
    shutil.rmtree(val_dir)
if os.path.exists(test_dir):
    shutil.rmtree(test_dir)
    
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# Split data menjadi train, validation, dan test
for category in categories:
    category_dir = os.path.join(output_dir, category)
    images = os.listdir(category_dir)
    
    # Pembagian train, validation, test (70%, 15%, 15%)
    train_images, val_test_images = train_test_split(images, test_size=0.4, random_state=42)
    val_images, test_images = train_test_split(val_test_images, test_size=0.5, random_state=42)
    
    # Pindahkan gambar-gambar ke dalam folder train, validation, dan test
    for img in train_images:
        target_dir = os.path.join(train_dir, category)
        os.makedirs(target_dir, exist_ok=True)
        shutil.move(os.path.join(category_dir, img), os.path.join(target_dir, img))

    for img in val_images:
        target_dir = os.path.join(val_dir, category)
        os.makedirs(target_dir, exist_ok=True)
        shutil.move(os.path.join(category_dir, img), os.path.join(target_dir, img))
        
    for img in test_images:
        target_dir = os.path.join(test_dir, category)
        os.makedirs(target_dir, exist_ok=True)
        shutil.move(os.path.join(category_dir, img), os.path.join(target_dir, img))

# %%
# Cetak jumlah gambar dalam folder train
print("\nJumlah Gambar dalam Folder Train:")
for category in categories:
    train_category_dir = os.path.join(train_dir, category)
    num_train_images = len(os.listdir(train_category_dir))
    print(f"{category}: {num_train_images} gambar")

# Cetak jumlah gambar dalam folder validation
print("\nJumlah Gambar dalam Folder Validation:")
for category in categories:
    val_category_dir = os.path.join(val_dir, category)
    num_val_images = len(os.listdir(val_category_dir))
    print(f"{category}: {num_val_images} gambar")

# Cetak jumlah gambar dalam folder test
print("\nJumlah Gambar dalam Folder Test:")
for category in categories:
    test_category_dir = os.path.join(test_dir, category)
    num_test_images = len(os.listdir(test_category_dir))
    print(f"{category}: {num_test_images} gambar")
# Out:
# Jumlah Gambar dalam Folder Train:
# bathroom: 444 gambar
# bedroom: 649 gambar
# dining: 706 gambar
# gaming: 906 gambar
# kitchen: 724 gambar
# laundry: 953 gambar
# living: 698 gambar
# office: 744 gambar
# terrace: 726 gambar
# yard: 838 gambar
#
# Jumlah Gambar dalam Folder Validation:
# bathroom: 148 gambar
# bedroom: 217 gambar
# dining: 236 gambar
# gaming: 302 gambar
# kitchen: 242 gambar
# laundry: 318 gambar
# living: 233 gambar
# office: 248 gambar
# terrace: 242 gambar
# yard: 280 gambar
#
# Jumlah Gambar dalam Folder Test:
# bathroom: 148 gambar
# bedroom: 217 gambar
# dining: 236 gambar
# gaming: 303 gambar
# kitchen: 242 gambar
# laundry: 318 gambar
# living: 233 gambar
# office: 249 gambar
# terrace: 242 gambar
# yard: 280 gambar

# %%
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def visualize_random_images(train_folder, val_folder, test_folder, num_images=1, figsize=(4, 4)):
    categories = os.listdir(train_folder)
    
    for category in categories:
        print(f"\nContoh Gambar untuk Kategori {category}:")
        fig, axes = plt.subplots(1, 3, figsize=(figsize[0] * 3, figsize[1]))

        folders = [train_folder, val_folder, test_folder]
        folder_names = ['Train', 'Validation', 'Test']
        
        for ax, folder, folder_name in zip(axes, folders, folder_names):
            category_dir = os.path.join(folder, category)
            images = os.listdir(category_dir)
            if len(images) > 0:
                img_file = random.choice(images)
                img_path = os.path.join(category_dir, img_file)
                img = mpimg.imread(img_path)
                ax.imshow(img)
                ax.axis("off")
                ax.set_title(folder_name)
            else:
                ax.axis("off")
                ax.set_title(f"No Images in {folder_name}")
        
        plt.show()

print('Visualizing Images for Categories:')
visualize_random_images(train_dir, val_dir, test_dir, figsize=(3, 3))
# Out:
# Visualizing Images for Categories:
#
# Contoh Gambar untuk Kategori bathroom:
# Contoh Gambar untuk Kategori dining:
# Contoh Gambar untuk Kategori yard:
# Contoh Gambar untuk Kategori gaming:
# Contoh Gambar untuk Kategori laundry:
# Contoh Gambar untuk Kategori kitchen:
# Contoh Gambar untuk Kategori terrace:
# Contoh Gambar untuk Kategori living:
# Contoh Gambar untuk Kategori office:
# Contoh Gambar untuk Kategori bedroom:

# %%
# Preprocess input images using MobilenetV3 preprocessing layers
preprocess_input = tf.keras.applications.mobilenet_v3.preprocess_input

# Menggunakan ImageDataGenerator untuk pelatihan 
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rescale=1./255,
    rotation_range=10, 
    zoom_range=0.1,
    width_shift_range=0.1, 
    height_shift_range=0.1, 
    shear_range=0.1,
    brightness_range=[0.8, 1.2],
    horizontal_flip=True,  
    vertical_flip=False,
    fill_mode='nearest'
)

traindata = train_datagen.flow_from_directory(
    directory=train_dir, 
    target_size=(224,224), 
    color_mode="rgb", 
    class_mode='categorical',
    shuffle=True)

val_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rescale=1./255
)

valdata = val_datagen.flow_from_directory(
    directory=val_dir, 
    target_size=(224,224), 
    color_mode="rgb", 
    class_mode='categorical',
    shuffle=False)

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rescale=1./255
)

testdata = test_datagen.flow_from_directory(
    directory=test_dir, 
    target_size=(224,224), 
    color_mode="rgb", 
    class_mode='categorical',
    shuffle=False)
# Out:
# Found 7385 images belonging to 10 classes.
# Found 2465 images belonging to 10 classes.
# Found 2461 images belonging to 10 classes.

# %%
print("Informasi Data Training:")
print(f"Jumlah sampel: {traindata.samples}")
print(f"Kelas: {traindata.class_indices}")
print(f"Shape gambar: {traindata.image_shape}")
print(f"Mode warna: {traindata.color_mode}")

print("\nInformasi Data Validasi:")
print(f"Jumlah sampel: {valdata.samples}")
print(f"Kelas: {valdata.class_indices}")
print(f"Shape gambar: {valdata.image_shape}")
print(f"Mode warna: {valdata.color_mode}")

print("\nInformasi Data Test:")
print(f"Jumlah sampel: {testdata.samples}")
print(f"Kelas: {testdata.class_indices}")
print(f"Shape gambar: {testdata.image_shape}")
print(f"Mode warna: {testdata.color_mode}")
# Out:
# Informasi Data Training:
# Jumlah sampel: 7385
# Kelas: {'bathroom': 0, 'bedroom': 1, 'dining': 2, 'gaming': 3, 'kitchen': 4, 'laundry': 5, 'living': 6, 'office': 7, 'terrace': 8, 'yard': 9}
# Shape gambar: (224, 224, 3)
# Mode warna: rgb
#
# Informasi Data Validasi:
# Jumlah sampel: 2465
# Kelas: {'bathroom': 0, 'bedroom': 1, 'dining': 2, 'gaming': 3, 'kitchen': 4, 'laundry': 5, 'living': 6, 'office': 7, 'terrace': 8, 'yard': 9}
# Shape gambar: (224, 224, 3)
# Mode warna: rgb
#
# Informasi Data Test:
# Jumlah sampel: 2461
# Kelas: {'bathroom': 0, 'bedroom': 1, 'dining': 2, 'gaming': 3, 'kitchen': 4, 'laundry': 5, 'living': 6, 'office': 7, 'terrace': 8, 'yard': 9}
# Shape gambar: (224, 224, 3)
# Mode warna: rgb

# %% [markdown]
# ### MODELING

# %%
from tensorflow.keras.applications import MobileNetV3Small

base_model = MobileNetV3Small(input_shape = (224, 224, 3), include_top = False, weights = 'imagenet')

# %%
# Freeze layers except the last 8 layers
for layer in base_model.layers[:-8]:
    layer.trainable = False

# %%
# Check if GPU is available
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    # Set memory growth for GPU
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# Physical devices cannot be modified after being initialized

# %%
from tensorflow import keras
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from keras.regularizers import l2
import tensorflow as tf


model = Sequential()
model.add(Input(shape=(224, 224, 3)))
model.add(base_model)
model.add(Conv2D(512, (3, 3), activation='elu'))
model.add(Conv2D(256, (3, 3), activation='elu'))
model.add(Conv2D(128, (3, 3), activation='elu'))
model.add(GlobalAveragePooling2D())
model.add(Dense(1024, activation='elu'))
model.add(Dense(512, activation='elu'))
model.add(Dense(256, activation='elu'))
model.add(Dense(len(categories), activation='softmax'))


model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ MobilenetV3small (Functional)   │ (None, 7, 7, 576)      │       939,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 5, 5, 512)      │     2,654,720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 3, 3, 256)      │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 1, 1, 128)      │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │       132,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,859,578 (22.35 MB)
#  Trainable params: 5,032,394 (19.20 MB)
#  Non-trainable params: 827,184 (3.16 MB)

# %%
from tensorflow.keras.optimizers import SGD  # Import SGD optimizer
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.callbacks import ReduceLROnPlateau


device_name = tf.test.gpu_device_name()

modelpath = './output/bestmodel.keras'

np.random.seed(42)

### train the model
with tf.device(device_name):
    
    optimizer = SGD()
    
    model.compile(
      optimizer=optimizer,
      loss='categorical_crossentropy',
      metrics=['accuracy'])
    
    # Early stopping for val_accuracy
    early_stopping_acc = EarlyStopping(monitor='val_accuracy', patience=10, 
                                       restore_best_weights=True, mode='max')

    # Early stopping for val_loss
    early_stopping_loss = EarlyStopping(monitor='val_loss', patience=5, 
                                        restore_best_weights=True, mode='min')

    
    # Reduce learning rate when a metric has stopped improving
    reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, 
                                  patience=8, min_lr=0.000005, verbose=1)

    
    # Callback ModelCheckpoint untuk menyimpan bobot terbaik
    checkpoint = ModelCheckpoint(
        modelpath,
        monitor='val_accuracy',
        save_best_only=True,  # Hanya menyimpan bobot terbaik
        mode='max',  # Mode untuk membandingkan nilai metrik (misalnya 'max' untuk akurasi)
        verbose=1  # Menampilkan pesan saat menyimpan
    )

    # Train the model
    history = model.fit(x=traindata, validation_data=valdata, epochs=200, 
                        batch_size=32, callbacks=[early_stopping_acc, early_stopping_loss,
                                                  checkpoint])
# Out:
# Epoch 1/200
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   1/231 ━━━━━━━━━━━━━━━━━━━━ 55:04 14s/step - accuracy: 0.1875 - loss: 2.2425
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1719386761.465242    1202 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.1533 - loss: 2.2764
# Epoch 1: val_accuracy improved from -inf to 0.11359, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 118s 452ms/step - accuracy: 0.1536 - loss: 2.2759 - val_accuracy: 0.1136 - val_loss: 2.5089
# Epoch 2/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.2240 - loss: 2.1308
# Epoch 2: val_accuracy improved from 0.11359 to 0.13144, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 95s 400ms/step - accuracy: 0.2240 - loss: 2.1308 - val_accuracy: 0.1314 - val_loss: 2.2914
# Epoch 3/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.2384 - loss: 2.0960
# Epoch 3: val_accuracy improved from 0.13144 to 0.18134, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 397ms/step - accuracy: 0.2384 - loss: 2.0960 - val_accuracy: 0.1813 - val_loss: 2.2300
# Epoch 4/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.2637 - loss: 2.0430
# Epoch 4: val_accuracy improved from 0.18134 to 0.19757, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 396ms/step - accuracy: 0.2637 - loss: 2.0431 - val_accuracy: 0.1976 - val_loss: 2.1931
# Epoch 5/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.2794 - loss: 2.0108
# Epoch 5: val_accuracy did not improve from 0.19757
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 391ms/step - accuracy: 0.2793 - loss: 2.0110 - val_accuracy: 0.1493 - val_loss: 2.2131
# Epoch 6/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.2776 - loss: 2.0137
# Epoch 6: val_accuracy improved from 0.19757 to 0.21501, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 94s 396ms/step - accuracy: 0.2776 - loss: 2.0136 - val_accuracy: 0.2150 - val_loss: 2.1615
# Epoch 7/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.2890 - loss: 2.0004
# Epoch 7: val_accuracy improved from 0.21501 to 0.23611, saving model to ./output/bestmodel.keras
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 393ms/step - accuracy: 0.2890 - loss: 2.0004 - val_accuracy: 0.2361 - val_loss: 2.1445
# Epoch 8/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.2911 - loss: 1.9848
# Epoch 8: val_accuracy did not improve from 0.23611
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 392ms/step - accuracy: 0.2911 - loss: 1.9848 - val_accuracy: 0.1473 - val_loss: 2.2331
# Epoch 9/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.2987 - loss: 1.9672
# Epoch 9: val_accuracy did not improve from 0.23611
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 389ms/step - accuracy: 0.2988 - loss: 1.9673 - val_accuracy: 0.1574 - val_loss: 2.1889
# Epoch 10/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.2954 - loss: 1.9629
# Epoch 10: val_accuracy did not improve from 0.23611
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 389ms/step - accuracy: 0.2954 - loss: 1.9628 - val_accuracy: 0.1826 - val_loss: 2.1438
# Epoch 11/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.3226 - loss: 1.9176
# Epoch 11: val_accuracy did not improve from 0.23611
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 393ms/step - accuracy: 0.3225 - loss: 1.9178 - val_accuracy: 0.1615 - val_loss: 2.1441
# Epoch 12/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.3072 - loss: 1.9340
# Epoch 12: val_accuracy did not improve from 0.23611
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 389ms/step - accuracy: 0.3072 - loss: 1.9340 - val_accuracy: 0.1797 - val_loss: 2.1592
# Epoch 13/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.3234 - loss: 1.9138
# Epoch 13: val_accuracy did not improve from 0.23611
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 390ms/step - accuracy: 0.3234 - loss: 1.9139 - val_accuracy: 0.1416 - val_loss: 2.2674
# Epoch 14/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.3194 - loss: 1.8990
# Epoch 14: val_accuracy did not improve from 0.23611
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 389ms/step - accuracy: 0.3193 - loss: 1.8991 - val_accuracy: 0.1744 - val_loss: 2.1560
# Epoch 15/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.3210 - loss: 1.9347
# Epoch 15: val_accuracy did not improve from 0.23611
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 93s 391ms/step - accuracy: 0.3209 - loss: 1.9346 - val_accuracy: 0.2041 - val_loss: 2.0839
# Epoch 16/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.3193 - loss: 1.9133
# Epoch 16: val_accuracy did not improve from 0.23611
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 387ms/step - accuracy: 0.3193 - loss: 1.9133 - val_accuracy: 0.2341 - val_loss: 2.0548
# Epoch 17/200
# 230/231 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.3285 - loss: 1.8964
# Epoch 17: val_accuracy did not improve from 0.23611
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 92s 386ms/step - accuracy: 0.3285 - loss: 1.8965 - val_accuracy: 0.2300 - val_loss: 2.0958

# %%
# Evaluasi model pada data test
test_loss, test_acc = model.evaluate(testdata)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_acc * 100:.2f}%')
# Out:
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 8s 100ms/step - accuracy: 0.1861 - loss: 2.0766
# Test Loss: 2.0079
# Test Accuracy: 23.61%

# %%
# Visualize the model

plt.plot(history.history['accuracy'], marker='o')
plt.plot(history.history['val_accuracy'], marker='o')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='lower right')
plt.show()

# %%
# Visualize the model accuracy including test accuracy
plt.plot(history.history['accuracy'], marker='o')
plt.plot(history.history['val_accuracy'], marker='o')

# Menambahkan test accuracy ke grafik
epochs = range(1, len(history.history['accuracy']) + 1)
plt.plot(epochs, [test_acc] * len(epochs), linestyle='--', marker='o')

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation', 'Test'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'], marker='o')
plt.plot(history.history['val_loss'], marker='o')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

# Prediksi label kelas menggunakan model terhadap data uji
predictions = model.predict(testdata)
predicted_classes = np.argmax(predictions, axis=1)

# Ambil label sebenarnya dari data uji
true_classes = testdata.labels

# Dapatkan nama kelas
class_labels = list(testdata.class_indices.keys())

# Buat classification matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Print classification matrix
print("Classification Matrix:")
print(cm)

# Print classification report
print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))

# %% [markdown]
# Accuracy adalah rasio dari jumlah prediksi yang benar (true predictions) dibagi dengan jumlah total instance dalam dataset.

# %% [markdown]
# Precision mengukur seberapa akurat model dalam memprediksi kelas positif. Ini dihitung sebagai rasio dari true positive (TP) dibagi oleh jumlah true positive dan false positive (FP).

# %% [markdown]
#  Recall mengukur seberapa baik model dalam menemukan semua instance yang benar dari kelas yang diinginkan. Ini dihitung sebagai rasio dari true positive (TP) dibagi oleh jumlah true positive dan false negative (FN).

# %% [markdown]
# F1-score adalah rata-rata harmonik dari precision dan recall. Ini memberikan keseimbangan antara precision dan recall.
